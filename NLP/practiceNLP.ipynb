# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/NLP/practiceNLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # To-DO
#
# 1. buat class yang berisi integrasi teknik stemming from nltk dan lemmatization from spacy.
# untuk input, buat method yang bisa menerima khusus untuk input list dan input string = alternatif 1
# ada yang lain?
#
# 2. tambahkan latihan based on reference dengan tingkatan soal yang berbeda lewat bantuan chat GPT

# %% [markdown]
# # sumber
# 1. versi mix: https://chatgpt.com/c/297418f3-0b93-46e0-92f2-d563b5470ce4

# %% [markdown]
# # Note

# %% [markdown]
# # Ilmu baru

# %% [markdown]
# ## Inner x outer method, tapi penting juga
# * outer disebut method class karena indentasi method pertama langsung setelah class
# * inner method bukan sebuah method class. artinya dia tidak bisa diberikan argumen self.

# %%
class Example:
    def outer_method(self): #outer disebut method class karena indentasi method pertama langsung setelah class
        angk= 3
        angka = 4
        def inner_method(angka): #inner method bukan sebuah method class. artinya dia tidak bisa diberikan argumen self.
            return angka
        # print("total = ", inner_method(angka) * angk)
        return inner_method(angka) * angk

        # Memanggil inner_method di dalam outer_method
        # inner_method()
    def another_met(self):
        p = self.outer_method() #walaupun inner berada dilingkup si outer_method aja, tapi dia bisa loh ditrasfer sampe ke method clas lain dengan tepat
        print(p * 2)

example = Example()
example.outer_method()
# Out:
# 12

# %%
example.another_met()
# Out:
# 24

# %% [markdown]
# ## penjelasan code dibalik PorterStemmer
# Tentu, saya bisa memberikan gambaran tentang bagaimana `PorterStemmer` bekerja. Algoritma Porter Stemmer adalah algoritma yang populer dan banyak digunakan untuk stemming, dan kode aslinya tersedia dalam beberapa bahasa pemrograman. Berikut adalah implementasi sederhana dari algoritma Porter Stemmer dalam Python:
#
# ```python
# class PorterStemmer:
#     def __init__(self):
#         self.vowels = "aeiou"
#         self.double_consonants = ["bb", "dd", "ff", "gg", "mm", "nn", "pp", "rr", "tt"]
#         self.li_ending = "cdeghkmnrt"
#         self.step_2_suffixes = {
#             "ational": "ate", "tional": "tion", "enci": "ence", "anci": "ance",
#             "izer": "ize", "bli": "ble", "alli": "al", "entli": "ent",
#             "eli": "e", "ousli": "ous", "ization": "ize", "ation": "ate",
#             "ator": "ate", "alism": "al", "iveness": "ive", "fulness": "ful",
#             "ousness": "ous", "aliti": "al", "iviti": "ive", "biliti": "ble",
#             "logi": "log"
#         }
#         self.step_3_suffixes = {
#             "icate": "ic", "ative": "", "alize": "al", "iciti": "ic",
#             "ical": "ic", "ful": "", "ness": ""
#         }
#
#     def is_consonant(self, word, i):
#         """Check if the letter at index i is a consonant."""
#         if word[i] in self.vowels:
#             return False
#         if word[i] == 'y':
#             if i == 0:
#                 return True
#             else:
#                 return not self.is_consonant(word, i - 1)
#         return True
#
#     def measure(self, word):
#         """Measure the number of consonant sequences (measures)."""
#         cv_seq = []
#         for i in range(len(word)):
#             if self.is_consonant(word, i):
#                 if not cv_seq or cv_seq[-1] != 'C':
#                     cv_seq.append('C')
#             else:
#                 if not cv_seq or cv_seq[-1] != 'V':
#                     cv_seq.append('V')
#         return cv_seq.count('VC')
#
#     def contains_vowel(self, stem):
#         """Check if the stem contains a vowel."""
#         for letter in stem:
#             if letter in self.vowels:
#                 return True
#         return False
#
#     def ends_double_consonant(self, word):
#         """Check if the word ends with a double consonant."""
#         return len(word) >= 2 and word[-2:] in self.double_consonants
#
#     def ends_cvc(self, word):
#         """Check if the word ends with consonant-vowel-consonant and the final consonant is not w, x, or y."""
#         if len(word) >= 3 and self.is_consonant(word, -1) and not self.is_consonant(word, -2) and self.is_consonant(word, -3):
#             if word[-1] not in "wxy":
#                 return True
#         return False
#
#     def step_1a(self, word):
#         if word.endswith("sses"):
#             return word[:-2]
#         if word.endswith("ies"):
#             return word[:-2]
#         if word.endswith("ss"):
#             return word
#         if word.endswith("s"):
#             return word[:-1]
#         return word
#
#     def step_1b(self, word):
#         if word.endswith("eed"):
#             stem = word[:-3]
#             if self.measure(stem) > 0:
#                 return stem + "ee"
#             return word
#         if word.endswith("ed"):
#             stem = word[:-2]
#             if self.contains_vowel(stem):
#                 return self.step_1b2(stem)
#             return word
#         if word.endswith("ing"):
#             stem = word[:-3]
#             if self.contains_vowel(stem):
#                 return self.step_1b2(stem)
#             return word
#         return word
#
#     def step_1b2(self, word):
#         if word.endswith("at") or word.endswith("bl") or word.endswith("iz"):
#             return word + "e"
#         if self.ends_double_consonant(word):
#             return word[:-1]
#         if self.measure(word) == 1 and self.ends_cvc(word):
#             return word + "e"
#         return word
#
#     def step_1c(self, word):
#         if word.endswith("y"):
#             stem = word[:-1]
#             if self.contains_vowel(stem):
#                 return stem + "i"
#         return word
#
#     def step_2(self, word):
#         for suffix, replacement in self.step_2_suffixes.items():
#             if word.endswith(suffix):
#                 stem = word[:-len(suffix)]
#                 if self.measure(stem) > 0:
#                     return stem + replacement
#         return word
#
#     def step_3(self, word):
#         for suffix, replacement in self.step_3_suffixes.items():
#             if word.endswith(suffix):
#                 stem = word[:-len(suffix)]
#                 if self.measure(stem) > 0:
#                     return stem + replacement
#         return word
#
#     def step_4(self, word):
#         suffixes = ["al", "ance", "ence", "er", "ic", "able", "ible", "ant", "ement", "ment", "ent", "ou", "ism", "ate", "iti", "ous", "ive", "ize"]
#         for suffix in suffixes:
#             if word.endswith(suffix):
#                 stem = word[:-len(suffix)]
#                 if self.measure(stem) > 1:
#                     return stem
#         if word.endswith("ion"):
#             stem = word[:-3]
#             if self.measure(stem) > 1 and (stem.endswith("s") or stem.endswith("t")):
#                 return stem
#         return word
#
#     def step_5a(self, word):
#         if word.endswith("e"):
#             stem = word[:-1]
#             if self.measure(stem) > 1 or (self.measure(stem) == 1 and not self.ends_cvc(stem)):
#                 return stem
#         return word
#
#     def step_5b(self, word):
#         if self.measure(word) > 1 and self.ends_double_consonant(word) and word.endswith("l"):
#             return word[:-1]
#         return word
#
#     def stem(self, word):
#         word = word.lower()
#         word = self.step_1a(word)
#         word = self.step_1b(word)
#         word = self.step_1c(word)
#         word = self.step_2(word)
#         word = self.step_3(word)
#         word = self.step_4(word)
#         word = self.step_5a(word)
#         word = self.step_5b(word)
#         return word
#
# # Contoh penggunaan
# stemmer = PorterStemmer()
# words = ["easily", "running", "better"]
# stemmed_words = [stemmer.stem(word) for word in words]
#
# print(stemmed_words)  # Output: ['easili', 'run', 'better']
# ```
#
# **Penjelasan Kode**:
#
# 1. **Konstruktor (`__init__` method):**
#    - Inisialisasi beberapa atribut yang akan digunakan dalam algoritma, seperti daftar vokal, konsonan ganda, dan beberapa aturan untuk tahap-tahap tertentu dalam stemming.
#
# 2. **Metode `is_consonant`:**
#    - Memeriksa apakah karakter pada posisi tertentu dalam kata adalah konsonan.
#
# 3. **Metode `measure`:**
#    - Menghitung jumlah pola konsonan-vokal dalam kata, yang disebut sebagai "measures".
#
# 4. **Metode `contains_vowel`:**
#    - Memeriksa apakah kata (stem) mengandung vokal.
#
# 5. **Metode `ends_double_consonant`:**
#    - Memeriksa apakah kata berakhir dengan dua konsonan yang sama.
#
# 6. **Metode `ends_cvc`:**
#    - Memeriksa apakah kata berakhir dengan pola konsonan-vokal-konsonan, dengan pengecualian untuk huruf "w", "x", atau "y".
#
# 7. **Langkah 1a hingga 1c:**
#    - Menghapus akhiran yang umum seperti "sses", "ies", "ss", dan "s", serta menangani akhiran "ed" dan "ing".
#
# 8. **Langkah 2 dan 3:**
#    - Mengganti akhiran tertentu berdasarkan aturan yang telah ditentukan jika measure cukup besar.
#
# 9. **Langkah 4 dan 5:**
#    - Menghapus atau mengganti akhiran berdasarkan kondisi yang lebih kompleks.
#
# 10. **Metode `stem`:**
#     - Menggabungkan semua langkah untuk mengurangi kata menjadi bentuk dasarnya.
#
# Ini adalah gambaran dasar dari algoritma Porter Stemmer. Implementasi aslinya bisa lebih kompleks dan memiliki lebih banyak rincian, tetapi contoh ini memberikan ide dasar tentang bagaimana algoritma tersebut bekerja.

# %% [markdown]
# # QNA

# %% [markdown]
# # Part of Exercise

# %% [markdown]
# ## Exercise Tokenization

# %% [markdown]
# (1) Think stats is a free book to study statistics (https://greenteapress.com/thinkstats2/thinkstats2.pdf)
#
# This book has references to many websites from where you can download free datasets. You are an NLP engineer working for some company and you want to collect all dataset websites from this book. To keep exercise simple you are given a paragraph from this book and you want to grab all urls from this paragraph using spacy

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
this of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
and the European Social Survey at http://www.europeansocialsurvey.org/.
this is elon mask: Tony gave two $ to Peter, Bruce gave 500 € to Steve.
'''

# TODO: Write code here
# Hint: token has an attribute that can be used to detect a url
import spacy
class Tokenization:
    def __init__(self, text):
        self.text = text
    def looking_for_url(self):
        nlp = spacy.blank("en")
        for token in nlp(self.text):
            if token.like_url:
                print(token.text)

    def looking_for_currency(self):
        nlp = spacy.blank("en")
        currency = nlp(self.text)
        wadah = []
        for token in currency:
            if token.is_currency:
                wadah.append(token.text)
            elif token.like_num:
                wadah.append(token.text)
        print(wadah)

p = Tokenization(text)
p.looking_for_url()
p.looking_for_currency()
# Out:
# http://www.data.gov/
# http://www.science
# http://data.gov.uk/.
# http://www3.norc.org/gss+website/
# http://www.europeansocialsurvey.org/.
# ['two', '$', '500', '€']

# %% [markdown]
# (2) Extract all money transaction from below sentence along with currency. Output should be,
#
# two $
#
# 500 €

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
# versi 1
# transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
# doc = nlp(transactions)
# for token in doc:
#     if token.like_num and doc[token.i+1].is_currency:
#         print(token.text, doc[token.i+1].text)
# versi 2
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
doc = nlp(transactions)
for i, token in enumerate(doc):
    if token.like_num and doc[token.i+1].is_currency: #apakah and itu seakan menggandakan subjek? misal a dan ... nah keknya and ni otomatis deh kalo kita pasang a dan a setelhanya a kedua otomatis sama subjeknya.
        print(token.text, doc[token.i+1].text)
# Out:
# 2024-07-27 03:24:41.876123: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-27 03:24:42.182177: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-27 03:24:43.337928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-27 03:24:47.320520: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# two $
# 500 €

# %% [markdown]
# ##                   **Stemming and Lemmatization: Exercises**

# %% [markdown]
# - **let import necessary libraries and create the object**

# %%
#for nltk
import nltk
from nltk.stem import PorterStemmer
#downloading all neccessary packages related to nltk
nltk.download('all')
#for spacy
import spacy
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/user/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /home/user/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/user/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /home/user/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/user/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %% [markdown]
# **Exercise1:**
# - Convert these list of words into base form using Stemming and Lemmatization and observe the transformations
# - Write a short note on the words that have different base words using stemming and Lemmatization

# %% [markdown]
# * definisi stemming:  achieves the base word by removing the suffixes [ing, ly etc] then the word will converting to the base form. Artinya dia itu hanya menghapus bagian imbuhan belakang pada kata atau surfix.
# * definisi lemmatization: uses the dictionary meanings while converting to the base form. Artinya dia itu mengubah kata ke dalam bentuk dasar sesuai kamus.

# %%
text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""

lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']

# %%
# bahan insipirasi buat memperbaiki .join() pada tanda baca
string = ["asem", ".", "as"]
for i in range(len(string)):
    if string[i] == ".":
        result = ''.join(string[i-1] + string[i] + " " + ''.join(string[i+1]))
        break
print(result)
# Out:
# asem. as

# %% [markdown]
# **part 1 done**

# %%
import spacy

class Lemmatizer:
    def __init__(self, text):
        self.text = text
        self.nlp = spacy.load('en_core_web_sm')
        self.obj_lemma = self.nlp(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.obj_lemma]
        self.custom = self.nlp.get_pipe('attribute_ruler')
        self.merge = ' '.join(self.lemma_spacy)
    def token_before_lemma(self):
        print(f"Token text before lemma process: {self.obj_lemma}\n")
    def token_after_lemma(self):
        print(f"Token text after lemma process: {self.lemma_spacy}\n")
    def custom_lemma_token(self):
        self.custom.add(patterns=[[{"TEXT" : "talented"}]], attrs={"LEMMA" : "talent"})
        self.custom.add(patterns=[[{"TEXT" : "dancing"}]], attrs={"LEMMA" : "dance"})
        self.custom.add(patterns=[[{"TEXT" : "running"}]], attrs={"LEMMA" : "run"})
        self.custom.add(patterns=[[{"TEXT" : "singing"}]], attrs={"LEMMA" : "sing"})
        self.custom.add(patterns=[[{"TEXT" : "fishing"}]], attrs={"LEMMA" : "fish"})
        self.custom.add(patterns=[[{"TEXT" : "\n"}]], attrs={"LEMMA" : " "})

    def token_after_customisasi(self):
        self.custom_lemma_token()
        self.obj_lemma = self.nlp(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.obj_lemma]
        print(f"Token text after lemma customisasi: {self.lemma_spacy}\n")
    def lemmatization(self):
        self.merge = ' '.join(self.lemma_spacy)
        print(f"{self.merge}")


text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""
obj = Lemmatizer(text)
obj.token_before_lemma()
obj.token_after_lemma()
obj.custom_lemma_token()
obj.token_after_customisasi()
obj.lemmatization()
# Out:
# Token text before lemma process: Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
# habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
#
#
# Token text after lemma process: ['Latha', 'be', 'very', 'multi', 'talented', 'girl', '.', 'she', 'be', 'good', 'at', 'many', 'skill', 'like', 'dancing', ',', 'running', ',', 'singing', ',', 'play', '.', 'she', 'also', 'like', 'eat', 'Pav', 'Bhagi', '.', 'she', 'have', 'a', '\n', 'habit', 'of', 'fishing', 'and', 'swim', 'too', '.', 'besides', 'all', 'this', ',', 'she', 'be', 'a', 'wonderful', 'at', 'cook', 'too', '.', '\n']
#
# ...

# %% [markdown]
# **QNA**
# 1. Gw bingung. tokenisasi menghasilkan teks. kalo diinput ke stemming sangat bisa. Namun, kalo diinput ke lemma harus ngemerge ya kan lucu masa ngerevert proses tokenisasi. lemmatization spacy wajib string. gimana biar bisa semuanya terintegrasi dengan baik?
# 1. Gw mikir kalo pengen buat sistem yang fleksibel dan kompeten harus ada integrasi. Konsep antisipasi(memaksimalkan
# potensi sistem agar bisa bekerja secara kompeten atas segala kemungkinan yang muncul) dan konsep fleksibel(berusaha untuk memperbarui secara aktif kemungkinan yang sistem belum dapat menghandle anomali yang muncul). Jadi, gw pengen buat sistem yang bisa mendapat irisan diantara dua konsep itu dalam proyek ini. untuk konsep fleksible oke gw paham caranya, tapi untuk konsep antisipasi gimana ya caranya? keknya perlu belajar machine learning sih. adakah cara lain gitu yang bisa gw gunakan?
# : sementara waktu gw bakal pakai yang fleksible dulu sih.

# %%
# versi pewarisan referensi
class Preprocessing:
    def __init__(self, text):
        self.text = text
class Tokenization(Preprocessing):
    def __init__(self, text):
        self.text = text
class Stemming(tokenization):
    def __init__(self, text):
        self.text = text
class Lemmatization(Stemming):
    def __init__(self, text):
        self.text = text

# %%
class Preprocessing:
    def __init__(self, text):
        self.text = text
        # for stemming
        self.obj_stemm = PorterStemmer()
        # for lemmatization
        self.obj_lemma = spacy.load('en_core_web_sm')
    def custom_stemmer(self, word):
        corrections = {
            "easili": "easy",
            "doubli" : "double",
            "veri" : "very",
            "thi" :  "this",
            "mani" : "many",
            "danc" : "dance",
            "besid" : "beside"
        } #var lokal si method ini. tdk semua var harus digantung kan ke self
        return corrections.get(word, word) #function get itu bisa mencari kata dalam dict dan jika kata itu ditemukan(ada pengganti seperti di atas) maka output bisa berubah, tapi jika kata itu tidak ditemukan maka ouput tetap sama kayak default/sebelum masuk ke funct get()
    def stemming_nltk(self):
        # self.stemmed = [self.obj_stemm.stem(word) for word in self.text] #pecahan yang sudah terproses
        self.lemmatization_spacy() #versi lemma duluan baru stemming.
        self.stemmed = [self.obj_stemm.stem(word) for word in self.lemma_spacy] #pecahan yang sudah terproses
        self.stemming = [self.custom_stemmer(word) for word in self.stemmed] #jadi, ini adalah var baru yang menyimpan valuehasil custom. bagi value yang berubah artinya dia termasuk kondisi yang dicari di method custom. sebaliknya jika tidak maka dia akan keluar sbg output default.
    def custom_lemma_token(self):
        self.obj_custom_lemma.add(patterns=[[{"TEXT" : "\n"}]], attrs={"LEMMA" : " "})

    def lemmatization_spacy(self):
        self.lemmated = self.obj_lemma(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.lemmated]
        self.obj_custom_lemma = self.obj_lemma.get_pipe('attribute_ruler')
        self.custom_lemma_token()
        self.lemmated = self.obj_lemma(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.lemmated]

    def output_display(self):
        self.lemmatization_spacy()
        self.stemming_nltk()
        # print(f"before lemma: {self.text}")
        print(f"after lemma: {self.lemma_spacy}")
        print(f"after stemming: {self.stemming}")
        # self.display = ' '.join(self.stemming)
        # print(f"after merge: {self.display}")
        # for i in range(len(self.stemming)):
        #     if self.stemming[i] == ".":
        #         result = ''.join(self.stemming[i-1]) + self.stemming[i] + " " + self.stemming[i+1]
        #         break
        # print(result)


# lst_words = ['easily', 'doubly', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']


text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""
obj = Preprocessing(text)
obj.output_display()
# Out:
# after lemma: ['Latha', 'be', 'very', 'multi', 'talented', 'girl', '.', 'she', 'be', 'good', 'at', 'many', 'skill', 'like', 'dancing', ',', 'running', ',', 'singing', ',', 'play', '.', 'she', 'also', 'like', 'eat', 'Pav', 'Bhagi', '.', 'she', 'have', 'a', ' ', 'habit', 'of', 'fishing', 'and', 'swim', 'too', '.', 'besides', 'all', 'this', ',', 'she', 'be', 'a', 'wonderful', 'at', 'cook', 'too', '.', ' ']
# after stemming: ['latha', 'be', 'very', 'multi', 'talent', 'girl', '.', 'she', 'be', 'good', 'at', 'many', 'skill', 'like', 'dance', ',', 'run', ',', 'sing', ',', 'play', '.', 'she', 'also', 'like', 'eat', 'pav', 'bhagi', '.', 'she', 'have', 'a', ' ', 'habit', 'of', 'fish', 'and', 'swim', 'too', '.', 'beside', 'all', 'this', ',', 'she', 'be', 'a', 'wonder', 'at', 'cook', 'too', '.', ' ']

# %% [markdown]
# **Exercise2:**
# - convert the given text into it's base form using both stemming from NLTK and lemmatization from spacy

# %%
# part 1 done
import spacy

class Lemmatizer:
    def __init__(self, text):
        self.text = text
        self.nlp = spacy.load('en_core_web_sm')
        self.doc = self.nlp(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.doc]
        self.custom = self.nlp.get_pipe('attribute_ruler')
        self.merge = ' '.join(self.lemma_spacy)
    def token_before_lemma(self):
        print(f"Token text before lemma process: {self.doc}\n")
    def token_after_lemma(self):
        print(f"Token text after lemma process: {self.lemma_spacy}\n")
    def custom_lemma_token(self):
        self.custom.add(patterns=[[{"TEXT" : "talented"}]], attrs={"LEMMA" : "talent"})
        self.custom.add(patterns=[[{"TEXT" : "dancing"}]], attrs={"LEMMA" : "dance"})
        self.custom.add(patterns=[[{"TEXT" : "running"}]], attrs={"LEMMA" : "run"})
        self.custom.add(patterns=[[{"TEXT" : "singing"}]], attrs={"LEMMA" : "sing"})
        self.custom.add(patterns=[[{"TEXT" : "fishing"}]], attrs={"LEMMA" : "fish"})
        self.custom.add(patterns=[[{"TEXT" : "\n"}]], attrs={"LEMMA" : " "})

    def token_after_customisasi(self):
        self.custom_lemma_token()
        self.doc = self.nlp(self.text)
        self.lemma_spacy = [token.lemma_ for token in self.doc]
        print(f"Token text after lemma customisasi: {self.lemma_spacy}\n")
    def lemmatization(self):
        self.merge = ' '.join(self.lemma_spacy)
        print(f"{self.merge}")


text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""
obj = Lemmatizer(text)
obj.token_before_lemma()
obj.token_after_lemma()
obj.custom_lemma_token()
obj.token_after_customisasi()
obj.lemmatization()
# Out:
# Token text before lemma process: Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
# habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
#
#
# Token text after lemma process: ['Latha', 'be', 'very', 'multi', 'talented', 'girl', '.', 'she', 'be', 'good', 'at', 'many', 'skill', 'like', 'dancing', ',', 'running', ',', 'singing', ',', 'play', '.', 'she', 'also', 'like', 'eat', 'Pav', 'Bhagi', '.', 'she', 'have', 'a', '\n', 'habit', 'of', 'fishing', 'and', 'swim', 'too', '.', 'besides', 'all', 'this', ',', 'she', 'be', 'a', 'wonderful', 'at', 'cook', 'too', '.', '\n']
#
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = "ate is looking at buying U.K. startup for $1 billion"
doc = nlp(text)
print(doc)
# Out:
# ate is looking at buying U.K. startup for $1 billion

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
this of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
and the European Social Survey at http://www.europeansocialsurvey.org/.
this is elon mask: Tony gave two $ to Peter, Bruce gave 500 € to Steve.
'''
doc = nlp(text)
# Suggested code may be subject to a license. Learn more: ~LicenseLog:1953471753.
for token in doc:
    print(token.like_url)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ## versi mix

# %% [markdown]
# **ide lain**
# 1. di level inter/advance data yang digunakan bisa dalam bentuk dataset/text. Tujuanya agar gw bisa semakin melatih skill lain kayak pandas or exception yang lebih expert

# %% [markdown]
# **Basic Level: Case Study - Customer Feedback Analysis**
# Title: Tokenization and Basic Preprocessing of Customer Reviews
#
# Description: You are working with a dataset of customer reviews for an e-commerce platform. Your task is to perform basic preprocessing to prepare the text data for further analysis.
#
# Scenario: The dataset contains customer reviews of various products. These reviews are in plain text format, and your goal is to break down the text into meaningful units.
#
# Task:
#
# Tokenization: Break the reviews into individual words (tokens).
# Stop Words Removal: Remove common stop words to clean the text.
# Lowercasing: Convert all words to lowercase for uniformity.
# Expected Output:
#
# A list of tokenized words for each review with stop words removed and converted to lowercase.

# %%
p = """
The laptop is amazing, works really fast!.
Horrible service, I am not satisfied with the product.
Great quality, but the delivery was delayed.
The product is just okay, nothing special.
Excellent customer service and fast shipping!
"""
