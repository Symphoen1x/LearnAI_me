# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/NLP/Deep_learning_for_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RoadMap
# Basic Deep Learning Concepts (5 Days)
#
# ANN: Working of Multi-Layered Neural Network
#
# Forward Propagation, Backward Propagation
#
# Activation Functions, Loss Functions
#
# Optimizers
#
# Advanced NLP Concepts (6+ Days)
#
# RNN, LSTM RNN
#
# GRU RNN
#
# Bidirectional LSTM RNN
#
# Encoder-Decoder, Attention Mechanisms, Seq2Seq
#
# Transformers
#
#
# Roadmap versi sumber cek notebook

# %% [markdown]
# # Algotitma learning theory
# 1. baca dulu materinya dan mengkritisi sampai paham dan tidak ada kebingungan
# 3. catat informasi dari sumber by QNA buat pemantik poin materi biar gw bisa recap by memori otak/pemahaman di step sebelumnya
# 4.  Elaborasi setelah gw kritisasi dan menyelesaikan per sub topik biar ga cepat lupa dan bisa menerapkan teknik fenyman yang serasa mengajar. Tapi disini gw mau integrasi dengan AI buat dua arah ataupun korektornya
# 4. Terakhir biar lebih bervalue gw mau dokumentasi hasil belajar, tapi per topik bukan per subnya. benefitnya banyak pren.
#
# # algoritma learning practic
# 1. pahami implementasi code beberapa library dari sumber terbaik alias dokumentasi sumbernya untuk memahami fitur-fitur dan parameternya(usahakan fokus pada bagaimana library sesuai dengan konsep dasar yang dipelajari di teori)
# 2. sering-sering memanfaatkan python code upper intermediate jangan yang instan mulu karena biar terasah juga skill konsep dan logika.
#
# [optional]
# 1. Ada sumber lain ga cuma satu. Ya ini ga kalah penting karena biar gw lebih ekstra dalam memahami sesuatu mungkin gw bisa lebih cepet paham dari sumber lain daripada harus maksa belajar di satu sumber yang cukup kurang jelas. Gw juga bisa dapat insight lebih sih kalo punya sumber lebih dari 1.
# 2. coba ulik apa yang membedakan kemampuan dan hasil library satu denga lainya
# 3. Latihan praktik prograaming terutama python ini juga ga kalah penting karena gw bisa lebih punya kompeten dari segi praktik juga mengasah logika lebih deep buat ranah lain yang bisa mendukung skill general gw.

# %% [markdown]
# # Main sumber
# * YT code basic : https://www.youtube.com/playlist?list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO
# * dicoding : https://www.dicoding.com/academies/185/tutorials/37403
# * gfg text book: https://www.geeksforgeeks.org/deep-learning-tutorial/?ref=previous_article
# * chatGPT :
#
# Roadmap:
# cek notebook one note

# %% [markdown]
# # Note
# (kurang apa atau perlu apa setelah belajar sebelum besok dilanjutkan atau lainya)

# %% [markdown]
# # Target today
# [time]-[input: topic objektif learning]-[spesifik link]-[output]
# 1. 11/11/24-
# 2. 13/11/24-pengenalan konsep NN-https://www.geeksforgeeks.org/neural-networks-a-beginners-guide/?ref=next_article - done baca dan kritisi, tapi belum paham dan step lanjutan.

# %% [markdown]
# # extract data to collecting information
# # Theory:
# * Neural network
# 1. bagaimana ceritanya model komputasi ANN ini secanggih itu dalam mengenali pola mungkin klasifikasi/prediksi/dll? hold
# 2. gambaran sebuah masalah linear secara terpisah dapat diselesaikan oleh perceptron jaringan satu lapis gimana ya?
# 3. masih ga kebayang gimana si fungsi aktivasi ini bekerja di NN?
# 4. Dijelaskan terkait perbedaan supervised dan unsupervised learning dalam konteks nerual network berkaitan dengan adanya instruktur yang mengawasi dalam hal output dari NN ini yang teruntuk supervised sendiri diketahui bahwa dia punya instruktur yang akan membadingkan keluaran yang dihasilkan oleh NN dan keluaran yang diinginkan oleh nya sehingga untuk mengurangi kesalahan/eror maka parameter jaringan diubah secara berulang dan berhenti saat kinerja berada pada tingakt yang dapat diterima. sedangkan untuk unsupervised ini tidak memiliki isntruktur dan hanya digunakan untuk memodelkan pola dan hubungan data. Pertanyaanya:
# saya masih kurang konek kenapa unsupervised learning yang tanpa instruktur hanya bisa memodelkan kasus pola dan hubungan data seperti clustering dan asosiation? coba lebih jelaskan!
# 5. kenapa MLP menggunakan fungsi aktivasi nonlinear, apakah aritnya MLP hanya cocok untuk jenis jarignan syaraf yang unsupervised learning?
# 6. Permasalahan gradien yang hilang dalam RNN ini kenapa bisa?
# 7. bagaimana Neural Network menangani dan beradaptasi dengan kondisi baru dan belajar dari data baru tersebut?
# 8. katanya NN ini bisa memproses secara paralel sehingga dapat memproses banyak pekerjaan sekaligus dan efisien untuk komputasi, apakah karena dia punya banyak input dan dapat memperbanyak layer?
# 9. Sebagai model “kotak hitam”, jaringan saraf menimbulkan masalah dalam aplikasi penting karena sulit untuk memahami bagaimana mereka membuat keputusan. maksudnya bagaimana ya?
# 10. dalam fenomena overfitting, nerual network dapat menyimpan materi pelatihan ke dalam memori daripada mengidentifiaksi pola dalam data, maksudnya bagaimana ya?
# 11. apakah Dynamic Neural Networks juga menangani masalah supervised dan unsupervised?
# # Technical

# %% [markdown]
# # complex
# 1. Artificial Neural Network
# 2.

# %% [markdown]
# # QNA theory
# [ini nanti akhir dimasukin ke sini sementara masih di tampung dulu di extract data to collecting inform]

# %% [markdown]
# # QNA technique
# [ini nanti akhir dimasukin ke sini sementara masih di tampung dulu di extract data to collecting inform]

# %% [markdown]
# # !!! Praktik with library di bawah hold dulu karena gw belum paham theorynya dengan holistik
