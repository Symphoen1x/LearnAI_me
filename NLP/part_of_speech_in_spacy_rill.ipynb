# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/NLP/part_of_speech_in_spacy_rill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %% [markdown]
# <h3>POS tags</h3>

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Elon flew to mars yesterday. He carried biryani masala with him")
type(doc)
for token in doc:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# Elon  |  PROPN  |  proper noun
# flew  |  VERB  |  verb
# to  |  ADP  |  adposition
# mars  |  NOUN  |  noun
# yesterday  |  NOUN  |  noun
# .  |  PUNCT  |  punctuation
# He  |  PRON  |  pronoun
# carried  |  VERB  |  verb
# biryani  |  ADJ  |  adjective
# masala  |  NOUN  |  noun
# with  |  ADP  |  adposition
# him  |  PRON  |  pronoun

# %% [markdown]
# You can check https://v2.spacy.io/api/annotation for the complete list of pos categories in spacy.
#
# https://en.wikipedia.org/wiki/Preposition_and_postposition
#
# https://en.wikipedia.org/wiki/Part_of_speech

# %%
doc = nlp("Wow! Dr. Strange made 265 million $ on the very first day")

for token in doc:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# Wow  |  INTJ  |  interjection
# !  |  PUNCT  |  punctuation
# Dr.  |  PROPN  |  proper noun
# Strange  |  PROPN  |  proper noun
# made  |  VERB  |  verb
# 265  |  NUM  |  numeral
# million  |  NUM  |  numeral
# $  |  NUM  |  numeral
# on  |  ADP  |  adposition
# the  |  DET  |  determiner
# very  |  ADV  |  adverb
# first  |  ADJ  |  adjective
# day  |  NOUN  |  noun

# %% [markdown]
# <h3>Tags</h3>

# %%
doc = nlp("Wow! Dr. Strange made 265 million $ on the very first day")

for token in doc:
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
# Out:
# Wow  |  INTJ  |  interjection  |  UH  |  interjection
# !  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Dr.  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Strange  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# made  |  VERB  |  verb  |  VBD  |  verb, past tense
# 265  |  NUM  |  numeral  |  CD  |  cardinal number
# million  |  NUM  |  numeral  |  CD  |  cardinal number
# $  |  NUM  |  numeral  |  CD  |  cardinal number
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# very  |  ADV  |  adverb  |  RB  |  adverb
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# day  |  NOUN  |  noun  |  NN  |  noun, singular or mass

# %% [markdown]
# ### Cara membedakan antara pos dengan tag
# Dalam konteks *POS tagging* menggunakan spaCy, `pos_` dan `tag_` memang terlihat mirip, tetapi mereka sebenarnya memiliki perbedaan yang signifikan. Berikut adalah penjelasan perbedaan antara keduanya:
#
# 1. **POS (Part of Speech) - `pos_`:**
#    - `pos_` mengacu pada kelas kata yang lebih umum, seperti kata benda (*noun*), kata kerja (*verb*), kata sifat (*adjective*), dll.
#    - Ini memberikan informasi yang lebih umum dan biasanya merupakan kategori dasar dari kata tersebut.
#    - Contoh kategori POS adalah: `NOUN`, `VERB`, `ADJ`, `ADV`, `PROPN`, dll.
#
# 2. **Tag - `tag_`:**
#    - `tag_` memberikan informasi yang lebih spesifik mengenai bagian kata tersebut, biasanya dengan detail gramatikal tambahan.
#    - `tag_` berfungsi sebagai label POS yang lebih terperinci, sering kali bergantung pada bahasa yang digunakan.
#    - Contoh `tag_` untuk bahasa Inggris bisa termasuk: `NN` (noun singular), `NNS` (noun plural), `VBZ` (verb, third person singular present), `VBG` (verb, gerund or present participle), dll.
#    - Jadi, meskipun dua kata mungkin memiliki `pos_` yang sama, mereka bisa memiliki `tag_` yang berbeda karena nuansa gramatikal.
#
# **Contoh Penjelasan:**
#
# Untuk kata "made" dalam kalimat di atas:
# - **POS (`pos_`)**: `VERB` - Ini menunjukkan bahwa kata tersebut adalah kata kerja.
# - **Tag (`tag_`)**: `VBD` - Ini menunjukkan bahwa kata kerja tersebut dalam bentuk lampau (past tense).
#
# **Kesimpulan:**
# - `pos_` memberikan informasi tentang kategori umum kata.
# - `tag_` memberikan informasi lebih spesifik mengenai bentuk dan fungsi kata tersebut dalam kalimat.
#
# Dengan memahami perbedaan ini, Anda bisa melihat bagaimana analisis linguistik bisa dilakukan pada tingkat yang lebih mendalam.

# %% [markdown]
# <h3>In below sentences Spacy figures out the past vs present tense for quit </h3>

# %%
doc = nlp("He quits the job")

print(doc[1].text, "|", doc[1].tag_, "|", spacy.explain(doc[1].tag_))
# Out:
# quits | VBZ | verb, 3rd person singular present

# %%
doc = nlp("he goes to the job")

print(doc[1].text, "|", doc[1].tag_, "|", spacy.explain(doc[1].tag_))
# Out:
# goes | VBZ | verb, 3rd person singular present

# %% [markdown]
# <h3>Removing all SPACE, PUNCT and X token from text</h3>

# %% [markdown]
# Processing microsoft's earning report: https://www.microsoft.com/en-us/investor/earnings/fy-2022-q2/press-release-webcast

# %%
earnings_text="""Microsoft Corp. today announced the following results for the quarter ended December 31, 2021, as compared to the corresponding period of last fiscal year:

·         Revenue was $51.7 billion and increased 20%
·         Operating income was $22.2 billion and increased 24%
·         Net income was $18.8 billion and increased 21%
·         Diluted earnings per share was $2.48 and increased 22%
“Digital technology is the most malleable resource at the world’s disposal to overcome constraints and reimagine everyday work and life,” said Satya Nadella, chairman and chief executive officer of Microsoft. “As tech as a percentage of global GDP continues to increase, we are innovating and investing across diverse and growing markets, with a common underlying technology stack and an operating model that reinforces a common strategy, culture, and sense of purpose.”
“Solid commercial execution, represented by strong bookings growth driven by long-term Azure commitments, increased Microsoft Cloud revenue to $22.1 billion, up 32% year over year” said Amy Hood, executive vice president and chief financial officer of Microsoft."""

doc = nlp(earnings_text)

filtered_tokens = []

# for token in doc:
#     if token.pos_ not in ["SPACE", "PUNCT", "X"]:
#         filtered_tokens.append(token)


for token in doc:
    # before filtering space, punct, and x
    print(token," | ", token.pos_, " | ", spacy.explain(token.pos_))
    if (token.pos_ != "SPACE") and (token.pos_ != "PUNCT") and (token.pos_ != "x") :
        filtered_tokens.append(token)

# after filtering space, punct, and x
# for token in filtered_tokens:
#     print(token," | ", token.pos_, " | ", spacy.explain(token.pos_))
# Out:
# Microsoft  |  PROPN  |  proper noun
# Corp.  |  PROPN  |  proper noun
# today  |  NOUN  |  noun
# announced  |  VERB  |  verb
# the  |  DET  |  determiner
# following  |  VERB  |  verb
# results  |  NOUN  |  noun
# for  |  ADP  |  adposition
# the  |  DET  |  determiner
# quarter  |  NOUN  |  noun
# ended  |  VERB  |  verb
# December  |  PROPN  |  proper noun
# 31  |  NUM  |  numeral
# 2021  |  NUM  |  numeral
# as  |  SCONJ  |  subordinating conjunction
# compared  |  VERB  |  verb
# to  |  ADP  |  adposition
# the  |  DET  |  determiner
# corresponding  |  ADJ  |  adjective
# period  |  NOUN  |  noun
# of  |  ADP  |  adposition
# last  |  ADJ  |  adjective
# fiscal  |  ADJ  |  adjective
# year  |  NOUN  |  noun
# Revenue  |  NOUN  |  noun
# was  |  AUX  |  auxiliary
# $  |  SYM  |  symbol
# 51.7  |  NUM  |  numeral
# billion  |  NUM  |  numeral
# and  |  CCONJ  |  coordinating conjunction
# increased  |  VERB  |  verb
# 20  |  NUM  |  numeral
# %  |  NOUN  |  noun
# ...

# %% [markdown]
# * bentar, X itu apa?
# : other, cek aja di spacy webnya: https://v2.spacy.io/api/annotation

# %% [markdown]
# # exercise from code basic
# 1. Exercise for Spacy POS tutorial,
#
# You are parsing a news story from cnbc.com. News story is stores in news_story.txt which is available in this same folder on github. You need to,
# Extract all NOUN tokens from this story. You will have to read the file in python first to collect all the text and then extract NOUNs in a python list
# Extract all numbers (NUM POS type) in a python list
# Print a count of all POS tags in this story

# %%
import spacy

class posTaging:
    def __init__(self):
        self.text = ""
        self.listed_noun = []
        self.listed_num = []
        self.nlp = spacy.load("en_core_web_sm")

    def read_file(self, filename):
        try:
            with open(filename, 'r') as f:
                self.text = f.read()
                print(self.text)
        except IOError:
            print("Error: could not read file " + filename)

    def posXtag(self):
        doc = self.nlp(self.text)
        for token in doc:
            if token.pos_ in ["NOUN"] and token.text != "%":
                self.listed_noun.append(token)
                print(token.text, " | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
            elif token.pos_ in ["NUM"]:
                self.listed_num.append(token)
                print(token.text, " | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
    def countPosType(self):
        doc = self.nlp(self.text)
        pos_counts = doc.count_by(spacy.attrs.POS)
        # tanpa keterangan nama attrs pada pos
        print(pos_counts)
        # disertai keterangan nama attrs
        for pos_id, count in pos_counts.items():
            pos = doc.vocab[pos_id].text
            print(pos, "|", count)


# Usage example
p = posTaging()
p.read_file("news_story.txt")
print("\n" * 5)
p.posXtag()
print("\n" * 5)
p.countPosType()
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# The Last Garden
#
# In the heart of a concrete jungle, where skyscrapers cast permanent shadows and the air tasted of metal and exhaust, there existed a secret garden. It wasn't grand or expansive – just a small patch of green nestled between two abandoned buildings on 23rd Street. But to Sarah Chen, it was everything.
#
# ...
