# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/PythonLearn/pythonOOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Link soure:
# https://www.geeksforgeeks.org/python-programming-language-tutorial/#python-oops-concepts
# https://www.udemy.com/course/object-oriented-python-programming/learn/lecture/18241898#learning-tools

# %% [markdown]
# # Syarat:
# 1. baterai laptop wajib diatas 20%. kalo dibawah 20% stop cass dulu dan off tunggu sekitar 75% atau lebih.

# %% [markdown]
# # Metode
# 1. serap informasi: baca dulu, minimal 1 sub bab. Jika terasa masih bisa diserap secara intuitif: lanjut baca dan menambah paragraf. Jika dirasa satu sub bab sudah bingung dan tidak masuk sama sekali ke otak: stop dulu kritisi dengan methode dibawah.
# 2. kritisi:
# * kondisi ketika informsi yang diserap tidak masuk sama sekali ke otak, kontradiksi dengan fakta lain yang pernah dilihat atau pemahaman selama ini, banyak informasi asing yang perlu di define dulu apa maksudnya dalam konteks di informasi tersebut.
# * caranya: tandai/blok beberapa informasi yang masuk ke dalam indikasi diatas, buat qna sbg tujuan yang ingin dipahami, input ke AI dan minta jelaskan lebih sederhana dengan metode yang mudah dipahami/sederhana, ulik bila informasi semakin kompleks dan perlu di pahami satu per satu, uji coba di area percobaan bila perlu, jika sudah ketemu dan paham masuk ke step berikutnya
# 3. collecting dan catat by format qna dalam bab yang sesuai
# * kondisi ini ketika step sebelumnya kelar/exit.
# * tentukan, apkah itu informasi yang tanpa adanya visualisasi code atau perlu code implementasi atau sebuah complex?
# * jika sebuah complex define di area complex, tapi jangan kelamaan atau sifatnya diperbarui semakin kedepan. ambil intinya dulu.
# * jika hanya jawaban qna dan kurang perlu diimplementasikan dgn code: masukan ke bagian QNA
# * jika sebaliknya: tulis by format qna dengan menyesuaikan tempat umum(bab)
# 4. Cari ide untuk latihan sbg bentuk review dan melatih kreatifitas
# * kondisi ini terjadi diakhir dan diluar flow 3 step sebelumnya. Penting sih, tapi kalo ga ada waktu tersisa define dulu di bagian TO-DO nanti discheduling ulang.
# 5. latihan by level
# * kondisi diluar keempat step sebelumnya atau lebih tepatnya sesi lain dengan sks tertentu.
# * semakin rendah level jumlahnya semakin banyak.
# * level awal: sbg pembukan dan pemanasan. 3-5 soal lah.
# * level intermediate: sbg latihan lanjutan. 2-3 soal.
# * level advacne: sbg project. 1 aja untuk ini.

# %% [markdown]
# # complex
# 1. *OOP: konsep pemrogramman, using on objek,  mengolah, mengatur, mengoperasikan, kelas.*
# 2. class: wadah yang menjadi perwakilan umum dalam bentuk nama yang berisi atribut, method, dan objek OOP.
# 3. objek OOP: representasi dari suatu kelas yang menyimpan value attribute dan method.
# 4. self : parameter dalam konstruktor OOP Python yang menjadi sebuah argumen sebagai penanda/pointer sebuah attribute untuk menjadi attribute objek.
# 5.  init: konstruktor dalam OOP python yang berguna untuk menyimpan/mendefine suatu attribute dengan pointer self menjadi attribute objek yang value/nilainya di define dalam objek.
# 6. Attribute objek: variabel yang menjadi milik suatu objek OOP yang didefinisikan melalui konstruktor ataupun attribute class. attribute tersebut ditandai dengan self yang didefine bersamaan dalam konstruktor.
# 7. Attribute kelas: variabel yang menjadi miliki suatu kelas yang didefinisikan di dalam kelas diluar method ataupun konstruktor.
# 8. method class: method yang dimiliki oleh suatu class dalam OOP yang menyimpan argumen(umumnya self, tapi bebas) untuk keperluan pemanggilan dengan objek.
# 9. method objek method yang dimiliki khusus oleh objek yang menyimpan attribute objek melalui konsturktor dan menyimpan argumen self sebagai pointer atau juga menambah argumen lain untuk keperluan tertentu.
# 10. @classmethod: sebuah keyword sebuah method yang didefine ketika ingin menggunakan/mengoperasikan/memanipulasi attribute class melalui sebuah method dengan argumen hanya cls didalamnya.
# 11. @staticmethod: keyword method yang dipakai untuk mendefine sebuah method yang tujuanya tidak memiliki hubungan dengan attribute class dan attribute objek, tapi bisa dipanggil di area pemanggilan.
# 12. str method: sebuah method yang dibuat oleh pihak python untuk tujuan type return sebuah objek saja tanpa harus memanggil method/attribute, seperti proses debugging.
# 13. polimorfisme: konsep dalam OOP yang menyatakan persamaan sebuah method, tapi saling beranekaragam bentuknya.
# 14. @abstractmethod: method yang disediakan dari library standar python yang menjadi template/basis dan diimplementasikan oleh kelas lain dalam methodnya tanpa harus ada return output.
# 15. ABC adalah class yang menjadi bagian dari library standar python yang menyediakan keyword/code untuk mendefine @abstractmethod dalam sebuah argumen class.
# 17. Method Resolution Order/MRO: aturan yang digunakan oleh python dalam menentukan urutan pemanggilan kelas dalam struktur pewarisan. Intinya methode ini memastikan bahwa setiap pemanggilan class akan dipanggil sekali dengan urutan yang benar dan menghindari pemanggilan ganda atau konflik method.
# 18. C3 Linearization: Algoritma yang memastikan urutan pewarisan yang konsisten. algo ini digunakan pada methode MRO untuk menghormati urutan lokal, dan menghindari duplikasi.
# call method:
#
# 8. inheritance: konsep dalam OOP yang berfungsi untuk mewarisi attribute dan method dari kelas induk.
# * mewarisi maksudnya memiliki value/data yang didefine dikelas sebelumnya(parent class). Sementara, kelas yang mewarisinya disebut child class.
# * keuntunganya tentu efisiensi code yang beragam tujuan program karena bisa menambah banyak fitur di lain hal tanpa harus menulis berulangkali dan tanpa mengubahnya.
# * ada 4 jenis inheritance:
# * single inheritance: warisan yang hanya sebatas mewarisi kelas parent secara tunggal.
# * multilevel inheritance:
# * hierarki inheritance:
# * multiple inheritance:
#
#
# . super()
# 3. Perbedaan Penggunaan super() dan namaClass():
# * Intinya penggunaan super() dalam Python adalah cara khusus untuk memanggil metode/objek dari kelas induk, terutama dalam konteks inheritance.
# * sementara namaClass()merujuk pada referensi class yang menjadi anak.
# * super()fungsi yang akan  membuat kelas anak mewarisi semua metode dan properti dari induknya.
# * super() itu pemanggilan sebuah class saja tidak bisa mewakili banyak kelas jika dalam kelas yang diwakili masing-masing tidak didefine si super()
# * jika namaClass() itu bisa di define untuk mewakili sebuah kelas, tapi dalam kelas yang diwakili/child class tidak perlu define className() masing-masing.
# 4. Sebuah child class bisa di define dengan hanya:
# class Student(Person):
#   pass
# Namun, Lebih baik menggunakan function  __init__() karena function tersebut lebih baik dipakai dari pada keyword pass.
# Selain itu,  __init__() mengotomatiskan setiap kali class digunakan untuk membuat objke baru di child class.
#  __init__() membuat  si class child tidak lagi mewarisi induknya karena dia mengambil alih warisan  __init__() fuction class induk.

# %% [markdown]
# # QNA
# *  kenapa kelas dan objek memiliki attributenya masing-masing?
# Untuk tujuanya tentu agar lebih fleksibel dalam penggunaan di suatu program. Tujuan lain:  tribut yang merupakan sifat umum dan global dari semua objek ditempatkan sebagai atribut kelas, sementara sifat unik dan beragam untuk setiap objek ditempatkan sebagai atribut instance.
# * apakah benar jika kita melakukan sharing data attribute class ke suatu method class atau method netral atau staticmethod , pemanggilan method melalui objek tidak perlu diinisiasi value?<br>
# : ada alasan logis yang bisa dibilang itu benar. alasanya karena  valuenya sudah diinisiasi lewat attribute kelas, berbeda dengan lewat attribute objek yang hanya menyimpan value secara implisit.
#
# .

# %% [markdown]
# * bagaimana dengan __private__ dalam oop, apakah oop python juga ada?
# * apa itu __call__ method?

# %% [markdown]
# # percobaan area

# %% [markdown]
# ### jangan lupa ulik code dibawah!

# %% [markdown]
# The __call__ method in Python is a special method that allows an instance of a class to be called as if it were a function. When you define the __call__ method in a class, you can use the instances of that class as callable objects.
#
# Here's a breakdown of how it works:
#
# Defining the __call__ Method
# The __call__ method is defined within a class like any other method. The first parameter is always self, which refers to the instance of the class. Additional parameters can be defined based on what the method needs to do.
#
# more: https://chatgpt.com/c/8ff7d4ee-11e2-4fb6-b282-351449a9d008

# %%
# __call__ method implemen
class MyCallableClass:
    def __init__(self, value):
        self.value = value

    def __call__(self, new_value):
        print(f"Old value: {self.value}")
        self.value = new_value
        print(f"New value: {self.value}")

# Create an instance of the class
my_instance = MyCallableClass(10)

# Call the instance as if it were a function
my_instance(20)
# Out:
# Old value: 10
# New value: 20

# %% [markdown]
# # dot(.) keyword

# %% [markdown]
# ### Apasih kegunaan keyword dot(.) dalam oop, apakah seesensial itu?
# * Mengakses Atribut dan Metode:
# * Namespace: Digunakan untuk mengakses anggota dari namespace tertentu.

# %%
# Mengakses Atribut dan Metode, attribute bisa objek/class
class Person:
    s = "suka pisang?"
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name}. saya {Person.s}") #versi keduanya

person = Person("Alice", 30)
print(person.name)  # Mengakses atribut 'name'
person.greet()      # Memanggil metode 'greet
# Out:
# Hello, my name is Alice. saya suka pisang?
# Alice
# Hello, my name is Alice. saya suka pisang?

# %%
# Namespace: Digunakan untuk mengakses anggota dari namespace tertentu.
class Outer:
    class Inner:
        def display(self):
            print("Hello from Inner class")

outer = Outer()
inner = outer.Inner()
inner.display()
# Out:
# Hello from Inner class

# %% [markdown]
# # class

# %% [markdown]
# ### Bagaimana define kelas dan pemanggilan kelas?
# * nama umum yang bisa mewakili banyak entitas/objek unik yang memiliki attribute.
# * pemanggilan kelas itu ditampung di dalam nama entitas yang akan dipakai yang disebut juga dengan objek.

# %%
class mobil:
    pass

ferari = mobil()
jepp = mobil()

# %% [markdown]
# ### bagaimana attribute suatu kelas?
# * sama kayak sebuah variabel yang menyimpan sebuah value/data, tapi bedanya dia tidak berdiri sendiri, tapi menjadi milik kelas.

# %%
class mobil:
    jumlahBan: 4 #jumlah ban
    pass

# %% [markdown]
# kurang lebih isi attribute dibagi ke dalam 3 jenis seperti diatas

# %% [markdown]
# ### Bagaimana bentuk dan tujuan penggunaan attribute kelas di oop?
# 1. attribute kelas dapat digunakan dalam banyak bentuk dan tujuan.
# * bisa untuk formating output lewat method dengan tujuan sharing data,
# * bisa juga formating ouput lewat class dengan tujuan identitas asli attribute class,
# * mengisi value bool untuk tujuan kondisional,
# *  untuk mengidentifikasi methodnya kelas yang tidak termasuk kosntruktor,
# * untuk defaulut value dalam konsep inheritance.
# * untuk digunakan dalam @static_method

# %%
#  attribute class untuk formating output lewat method netral dengan tujuan sharing data
class Dog:

    # attribute class
    attr1 = "mammal"
    attr2 = "dog"

    # A sample method untuk bagian formating output
    def fun(no):
        print("I'm a", no.attr1)
        print("I'm a", no.attr2)

#ini yang disebut 'object' dibahas nanti lebih lanjut
Rodger = Dog()

# Accessing class attributes langsung
print(Rodger.attr1)
# share to method through objects
Rodger.fun()
# Out:
# mammal
# I'm a mammal
# I'm a dog

# %%
# bisa juga formating ouput lewat class dengan tujuan identitas asli/default/constanta attribute class
class Circle:
    pi = 3.14159 # attribute class default

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return Circle.pi * (self.radius ** 2) # memanggil attribute class disertai nama class

circle1 = Circle(5)
print(circle1.area())  # Output: 78.53975

# %%
# mengisi value bool untuk tujuan kondisional
class Application:
    debug_mode = True #inisialiasasi/awal pendeklarasian suatu value

    def __init__(self, name):
        self.name = name

    def run(self):
        if Application.debug_mode == True: #sharing dalam kondisional konsep
            print(f"{self.name} running in debug mode")
        else:
            print(f"{self.name} not running in debug mode")

app1 = Application("App1")
app2 = Application("App2")

app1.run()  # Output: Running App1
# Assignment/memperbarui nilai sebelumnya
Application.debug_mode = False
app2.run()  # Output: Running App1 in debug mode
# Out:
# App1 running in debug mode
# App2 not running in debug mode

# %%
#  untuk mengidentifikasi methodnya kelas yang tidak termasuk kosntruktor
class Student:
    count = 0

    def __init__(self, name): # argumen konstruktor atau attributenya si objek
        self.name = name

    @classmethod #keyword wajib
    def get_count(cls): #argumen yang berbeda dengan argumen konstruktor
        Student.count += 1
        return cls.count #sharing by argumen class

aria = Student("woy")
print(Student.get_count())  # Output: 2
# Out:
# 1

# %% [markdown]
# ### apakah attribute class bisa diubah/diganti valuenya di area class atau luar area class?

# %%
class Dog:
    # attribute class
    attr1 = "mammal"
    attr2 = "dog"

    # A sample method untuk bagian formating output
    def fun(no):
        print("I'm a", no.attr1)
        print("I'm a", no.attr2)
    @classmethod
    def ubah(cls):
        cls.attr1 = "monyet"
        cls.attr2 = "penyet"
        return f"dalam kelas: {cls.attr1} dan {cls.attr2}"



# Membuat instance
Rodger = Dog()
# Mengakses atribut kelas langsung melalui instance karena ada argumen no
print(Rodger.attr1)
Rodger.fun()

# dalam kelas
print(Dog.ubah())


# Mengubah nilai atribut kelas melalui kelas di luar kelas. ini rahasianya, yaitu dengan menaruh pointer kelas di luar kelas.
Dog.attr1 = "reptile"
Dog.attr2 = "lizard"



# Perubahan terlihat pada instance
print("luar kelas: ")
print(Rodger.attr1)
Rodger.fun()

# Membuat instance baru. ketika objek baru dibuat, attribute kelas yang
Tommy = Dog()

# Instance baru juga melihat perubahan atribut kelas
print(Tommy.attr1)  # Output: reptile
print(Tommy.attr2)  # Output: reptile
Tommy.fun()         # Output: I'm a reptile
                    #         I'm a lizard
# Out:
# mammal
# I'm a mammal
# I'm a dog
# dalam kelas: monyet dan penyet
# luar kelas:
# reptile
# I'm a reptile
# I'm a lizard
# reptile
# lizard
# I'm a reptile
# I'm a lizard

# %% [markdown]
# ### Apa perbedaan penggunaan @staticmethod, constructor method, dan @clashmethod  ?
# ada 3 perbedaan utama sebagai aspek yang harus dipertimbangkan:<br>
# **segi parameter**:  <br>
# * @staticmethod: Tidak menerima cls atau self.
# * constructor method: menerima argumen bebas sbg ketetapan, tapi lebih sering self.
# * @classmethod: Menerima cls.
#
# **segi akses**: <br>
# * @staticmethod: Tidak dapat mengakses atau memodifikasi atribut kelas atau instance.
# * constructor method: Dapat mengakses dan memodifikasi atribut kelas.
# * @classmethod: Dapat mengakses dan memodifikasi atribut kelas.
#
# **segi penggunaan**: <br>
# * @staticmethod: Digunakan untuk method yang tidak tergantung pada status kelas atau instance. biasanya method khusus untuk tujuan tertentu.
# * @classmethod: Digunakan untuk method yang perlu mengetahui atau memodifikasi variabel kelas.
# * constructor method: Digunakan untuk method yang perlu mengetahui atau memodifikasi variabel instance.

# %%
# contoh implemen @staticmethod
class MathOperations:
# Tidak dapat mengakses atau memodifikasi atribut kelas atau instance.
    @staticmethod
    # Tidak menerima cls atau self.
    def add(x, y):
        return x + y

# Memanggil metode statis tanpa membuat instance dari kelas
result = MathOperations.add(5, 3)
print(result)  # Output: 8
# Out:
# 8

# %%
class Validator:

    @staticmethod
    def is_positive(number):
        """Memeriksa apakah sebuah angka positif."""
        return number > 0

    @staticmethod
    def is_email_valid(email):
        """Memeriksa format email sederhana."""
        return "@" in email and "." in email

    @staticmethod
    def is_length_valid(string, min_length, max_length):
        """Memeriksa apakah panjang string berada dalam rentang tertentu."""
        return min_length <= len(string) <= max_length


# Contoh Penggunaan:
number = 10
email = "example@domain.com"
username = "user123"

# Validasi angka positif
print(Validator.is_positive(number))  # Output: True

# Validasi email
print(Validator.is_email_valid(email))  # Output: True

# Validasi panjang string
print(Validator.is_length_valid(username, 5, 10))  # Output: True
# Out:
# True
# True
# True

# %%
# implemen @classmethod
class MathOperations:
    factor = 2

    @classmethod
    # Dapat mengakses dan memodifikasi atribut kelas
    def multiply(cls, x):
        return x * cls.factor

    @classmethod
    # Digunakan untuk metode yang perlu mengetahui atau memodifikasi status kelas. Bisa juga untuk dimodifikasi dimethod lain ketika memanggil method lain.
    def set_factor(cls, new_factor):
        cls.factor = new_factor

# Memanggil metode kelas dari kelas
result = MathOperations.multiply(5)
print(result)  # Output: 10

# Mengubah nilai faktor
MathOperations.set_factor(3)
result = MathOperations.multiply(5)
print(result)  # Output: 15
# Out:
# 10
# 15

# %%
#implement object method
class Person():
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def display(self):
    print(self.name, self.age)

obj = Person("arman", "teluloro")
obj.display() #object method
# Out:
# arman teluloro

# %% [markdown]
# ### Apa itu pass keyword dan fungsinya dalam class atau method class?
# * tentunya dalam class atau method itu, si pass ini bisa untuk template yang ada di anak class.
# * bisa juga untuk menjalankan code lain yang diprioritaskan, tapi takut method ini hilang dari susunan list inisasi method awal sehingga walaupun dia ada dan nyala, tapi tidak bervalue/mengganggu/beroutput.

# %%
# contoh sbg template
class Shape:
    def __init__(self, name):
        self.name = name

    def area(self):
        pass  # Metode ini akan diimplementasikan di subclass

    def perimeter(self):
        pass  # Metode ini akan diimplementasikan di subclass

# Subclass yang mengimplementasikan metode area dan perimeter
class Circle(Shape):
    def __init__(self, radius):
        super().__init__("Circle")
        self.radius = radius

    def area(self):
        import math
        return math.pi * self.radius ** 2

    def perimeter(self):
        import math
        return 2 * math.pi * self.radius

# Contoh penggunaan
c = Circle(5)
print(f"Area of {c.name}: {c.area()}")
print(f"Perimeter of {c.name}: {c.perimeter()}")

# %%
# contoh sbg bantuan saat kondisi tidak ingin dia hilang/lupa
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def identitas(self):
        return f"{self.name}, {self.age} years old"
    def kerjaan(self):
        pass
p = Person("Alice", 30)
print(p.identitas())  # Output: Alice, 30 years old
# Out:
# Alice, 30 years old

# %% [markdown]
# ### apa fungsi str method? kapan dan kondisi apa itu digunakan?
# * fungsi dari method tersebut adalah untuk merepresntasikan output string yang didefine dalam method lain dengan tujuan masing-masing.
# * Kondisi yang membuat method _str_ digunakan:
#  ketika kita akan mendefine dan mengeluarkan output attribute objek melalui konstrukter ke sebuah objek yang menyimpan class saja. Kita perlu menggunakan __str__ sbg return type. Jika tidak dan kita hanya pakai print/return di method biasa, hasilnya akan keluar berupa output objek asli yang bentuknya tidak ramah untuk manusia, tapi ramah untuk komputer.

# %%
# jika memakai return/type di method biasa dengan tujuan konversi suatu nilai langsung ke objek tanpa method/attribute objek.
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def output(self):
        return f"{self.name}, {self.age} years old"
p = Person("Alice", 30)
print(p)
p.output()
# Out:
# ...
# 'Alice, 30 years old'

# %%
# jika memakai __str__ method
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return f"{self.name}, {self.age} years old"
p = Person("Alice", 30)
print(p)  # Output: Alice, 30 years old
# Out:
# Alice, 30 years old

# %% [markdown]
# ### Apa perbedaan method str() dan repr()
# sumber: https://realpython.com/python-repr-vs-str/
# __str__
# * Tujuan: Memberikan representasi string yang mudah dibaca oleh manusia.
# * Penggunaan: Digunakan ketika Anda menginginkan representasi objek yang ramah pengguna, biasanya untuk output pengguna akhir.
# * pemanggilan: bisa dengan print variabel
# __repr__
# * Tujuan: Memberikan representasi string yang lebih rinci dan formal yang dimaksudkan untuk debugging dan pengembangan. Representasi ini harus, jika memungkinkan, menjadi ekspresi valid yang dapat digunakan untuk merekonstruksi objek yang sama.
# * The reason there are two methods to display an object is that they have different purposes:
#
# .__repr__() provides the official string representation of an object, aimed at the programmer.
#
# .__str__() provides the informal string representation of an object, aimed at the user.
# * Penggunaan:
# .__repr__() : Digunakan ketika Anda membutuhkan representasi yang lebih teknis dan rinci dari objek, seperti dalam konteks debugging atau logging.
# .__str__() : Digunakan ketika Anda membutuhkan representasi yang lebih sederhana dan formal dari objek, seperti dalam output pengguna akhir. Ini akan lebih mudah dipahami pengguna.
# * pemanggilan: bisa dengan print variabel

# %%
# versi code from python
import datetime
today = datetime.datetime.now()
#for programmer
repr(today)
'datetime.datetime(2023, 2, 18, 18, 40, 2, 160890)'
today.__repr__()
'datetime.datetime(2023, 2, 18, 18, 40, 2, 160890)'
# Out:
# 'datetime.datetime(2023, 2, 18, 18, 40, 2, 160890)'

# %%
# for user
str(today)
'2023-02-18 18:40:02.160890'
today.__str__()
'2023-02-18 18:40:02.160890'
# Out:
# '2023-02-18 18:40:02.160890'

# %%
# versi manual
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def __repr__(self):
        class_name = type(self).__name__
        return f"{class_name}(title={self.title!r}, author={self.author!r})"

    def __str__(self):
        return f'"{self.title}" by {self.author}'

odyssey = Book("The Odyssey", "Homer")

print(repr(odyssey))
print(str(odyssey))
# Out:
# Book(title='The Odyssey', author='Homer')
# "The Odyssey" by Homer

# %% [markdown]
# ### Bagaimana cara memnaggil class dalam class lain?

# %% [markdown]
# **Menggunakan teknik komposisi**

# %%
class Engine:
    def __init__(self, horsepower):
        self.horsepower = horsepower

    def start(self):
        print("Engine started with horsepower:", self.horsepower)

class Car:
    def __init__(self, engine):
        self.engine = engine

    def start(self):
        self.engine.start()

# Membuat objek Engine
engine = Engine(150)
# Membuat objek Car dengan menyertakan engine sebagai atribut
car = Car(engine)

# Memanggil method start dari Car yang pada gilirannya memanggil method start dari Engine
# car.start()
# Out:
# Engine started with horsepower: 150

# %% [markdown]
# **Menggunakan inheritance**

# %%
class Animal:
    def sound(self):
        print("Some generic animal sound")

class Dog(Animal):
    def sound(self):
        # Memanggil method sound dari kelas induk (Animal)
        super().sound()
        # output sound kelas bawah
        print("Bark")

# Membuat objek Dog dan memanggil method sound
dog = Dog()
dog.sound()
# Out:
# Some generic animal sound
# Bark

# %% [markdown]
# **Kondisi lain: Menggunakan Inner Class (Kelas Dalam)**

# %%
class OuterClass:
    class InnerClass:
        def display(self):
            print("Inner class method")

    def __init__(self):
        self.inner = self.InnerClass()

    def show_inner(self):
        self.inner.display()

# Membuat objek OuterClass dan memanggil method dari InnerClass
outer = OuterClass()
outer.show_inner()
# Out:
# Inner class method

# %% [markdown]
# **Teknik ngide**

# %%
class A:
    def __init__(self):
        print("Ini adalah konstruktor A") #non variabel
        self.a = 10 #with variabel

class B:
    def __init__(self):
        # Membuat instance dari A di dalam B
        self.a = A()
        print("Ini adalah konstruktor B")
    def __str__(self):
        return f"Ini adalah objek a : {self.a.a}"

# Membuat objek B
b = B()
print(b)
# Out:
# Ini adalah konstruktor A
# Ini adalah konstruktor B
# Ini adalah objek a : 10

# %% [markdown]
# ### Bagaimana cara memanggil method yang ada di class lain di dalam class lainya?
# :
# urut berdasarkan rekomendasi
# * Komposisi dan Dependency Injection adalah metode yang paling direkomendasikan karena mereka mendukung prinsip OOP seperti enkapsulasi dan membuat kode lebih mudah untuk diuji dan dipelihara.
# * Inheritance adalah pilihan bagus ketika Anda ingin mendesain hubungan "is-a" antara kelas.
# * Classmethod/Staticmethod berguna untuk utilitas atau fungsi yang tidak bergantung pada state dari instance.
# * Membuat objek di dalam kelas bisa diterima, tetapi berhati-hatilah dengan pengelolaan dependency.
# * Memanggil metode langsung dari nama kelas harus digunakan dengan hati-hati karena dapat mengurangi fleksibilitas dan abstraksi.

# %% [markdown]
# **Menggunakan Komposisi (Composition)**
# Komposisi adalah pendekatan di mana satu kelas memiliki objek dari kelas lain sebagai atributnya, dan kemudian memanggil metode dari objek tersebut. Ini adalah salah satu pendekatan paling direkomendasikan karena mendukung enkapsulasi dan modularitas.

# %%
class Engine:
    def start(self):
        print("Engine started")

class Car:
    def __init__(self, engine):
        self.engine = engine  # Komposisi: Car memiliki objek Engine

    def start_engine(self):
        self.engine.start()  # Memanggil metode dari objek Engine

# Contoh penggunaan
engine = Engine()
# ini kuncinya
car = Car(engine)
car.start_engine()

# %% [markdown]
# **Menggunakan Inheritance (Pewarisan)**
# Dalam inheritance, kelas anak (child class) mewarisi semua metode dan atribut dari kelas induk (parent class). Metode dari kelas induk dapat dipanggil menggunakan super() atau secara langsung(constructor class induk) jika diperlukan.

# %%
class Parent:
    def greet(self):
        print("Hello from Parent")

class Child(Parent):
    def greet_and_more(self):
        super().greet()  # Memanggil metode dari kelas induk
        print("And hello from Child")

# Contoh penggunaan
child = Child()
child.greet_and_more()
# Out:
# Hello from Parent
# And hello from Child

# %% [markdown]
# **Menggunakan Dependency Injection**
# Dependency Injection adalah ketika objek yang dibutuhkan (dependency) diberikan (injected) ke dalam kelas melalui parameter, dan kemudian digunakan untuk memanggil metode.

# %%
class Logger:
    def log(self, message):
        print(f"Log: {message}")

class Application:
    def __init__(self, logger):
        self.logger = logger  # Dependency Injection
    #input in method as privacy
    def run(self):
        self.logger.log("Application started")

    #input for user as public
    # def run(self, alpha):
    #     self.logger.log(alpha)

# Contoh penggunaan
logger = Logger()
app = Application(logger)
# privacy pemanggilan
app.run()


# public pemanggilan
# p = "Application started"
# app.run(p)
# Out:
# Log: Application started

# %% [markdown]
# **Menggunakan Classmethod atau Staticmethod**
# ika metode tidak membutuhkan akses ke instance tertentu dari kelas, Anda bisa memanggilnya sebagai class method atau static method tanpa membuat instance dari kelas tersebut. Ini berguna untuk utilitas umum

# %%
class Utility:
    @staticmethod
    def add(a, b):
        return a + b

class Calculator:
    def calculate(self, x, y):
        return Utility.add(x, y)  # Memanggil static method dari kelas lain

# Contoh penggunaan
calc = Calculator()
print(calc.calculate(3, 4))
# Out:
# 7

# %% [markdown]
# **Menggunakan Objek yang Dibuat di dalam Kelas**
# Jika Anda ingin langsung membuat instance dari kelas lain di dalam metode atau konstruktor kelas, Anda bisa langsung memanggil metode dari objek tersebut.

# %%
class Printer:
    def print_message(self, message):
        print(message)

class Report:
    def show(self):
        printer = Printer()  # Membuat objek Printer di dalam metode
        printer.print_message("This is a report")

# Contoh penggunaan
report = Report()
report.show()
# Out:
# This is a report

# %% [markdown]
# ### Bagaimana cara memanggil method yang ada disuatu class dalam class yang sama?
# cek ini lengkap : https://chatgpt.com/c/21df28cc-1ca3-4c4c-bfba-5b1c6cf0281d

# %% [markdown]
# ### Apakah sebuah class bisa menjadi nested class?
# * jawabanya bisa, penggunaanya tergantung kebutuhan.
# * bisa digunakan pada NLP juga, ini contohnya!

# %%
class Outer:
    class Inner:
        def display(self):
            print("Hello from Inner class")
    def displayAlso(self):
        print("Hello from Outer class")
# pembuktian apabila si inner clas langsung dipanggil -> hasilnya akan eror dan tidak terdefine
# iner = Inner()
# iner.display()
# pembuktian apabila outter class dipanggil langsung -> hasilnya tentu normal
outer = Outer()
outer.displayAlso()

# solusi untuk class inner yang akan dipanggil -> hubungkan dahulu ke kelas outer:
outer = Outer()
inner = outer.Inner()  # begini cara manggilnya.
inner.display()
# Out:
# Hello from Outer class
# Hello from Inner class

# %%
class NLPProcessor:
    class Tokenizer:
        def tokenize(self, text):
            # Tokenization logic here
            return text.split()

    class Stemmer:
        def stem(self, word):
            # Stemming logic here
            return word.lower()  # A placeholder for actual stemming logic

    class Lemmatizer:
        def lemmatize(self, word):
            # Lemmatization logic here
            lemmas = {
                "running": "run",
                "ran": "run",
                "cars": "car",
                "children": "child"
            }
            return lemmas.get(word, word)

    class POSTagger:
        def pos_tag(self, tokens):
            # POS tagging logic here
            tags = {
                "This": "DT",
                "is": "VBZ",
                "an": "DT",
                "example": "NN",
                "sentence": "NN"
            }
            return [(token, tags.get(token, "NN")) for token in tokens]

    def __init__(self, use_stemming=True, use_lemmatization=True, use_pos_tagging=True):
        self.tokenizer = self.Tokenizer()
        self.stemmer = self.Stemmer() if use_stemming else None
        self.lemmatizer = self.Lemmatizer() if use_lemmatization else None
        self.pos_tagger = self.POSTagger() if use_pos_tagging else None

    def process(self, text):
        tokens = self.tokenizer.tokenize(text)

        if self.stemmer:
            tokens = [self.stemmer.stem(token) for token in tokens]

        if self.lemmatizer:
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]

        if self.pos_tagger:
            tokens = self.pos_tagger.pos_tag(tokens)

        return tokens

# Using the NLPProcessor
nlp = NLPProcessor()
# processed_text = nlp.process("This is an example sentence.")
processed_text = nlp.process("The cake was baked perfectly by the chef.")

print(processed_text)

# Testing different configurations
nlp_no_stemming = NLPProcessor(use_stemming=False)
print(nlp_no_stemming.process("This is an example sentence."))

nlp_no_lemmatization = NLPProcessor(use_lemmatization=False)
print(nlp_no_lemmatization.process("This is an example sentence."))

nlp_no_pos_tagging = NLPProcessor(use_pos_tagging=False)
# print(nlp_no_pos_tagging.process("This is an example sentence."))
# Out:
# [('the', 'NN'), ('cake', 'NN'), ('was', 'NN'), ('baked', 'NN'), ('perfectly', 'NN'), ('by', 'NN'), ('the', 'NN'), ('chef.', 'NN')]
# [('This', 'DT'), ('is', 'VBZ'), ('an', 'DT'), ('example', 'NN'), ('sentence.', 'NN')]
# [('this', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('example', 'NN'), ('sentence.', 'NN')]

# %% [markdown]
# # Objek

# %% [markdown]
# ### bagaimana bentuk objek?
# objek ini bentuknya seperti variable, tapi dia adalah representasi kelas dalam OOP yang lebih spesifik.

# %%
objek = Mobil()
objek2 = Mobil("merah", 120000000)

# %% [markdown]
# ### bagaimana bentuk attribute objek dan cara menghubungkanya ke objek?
# * sebenarnya, attribute objek itu bisa mengambil dari attributenya si class juga bisa mengambil/menginisiasi dari konstruktor.
# * cara menghubungkan untuk attribute objek yang diambil dari class adalah dengan menyandingkan nama objek dengan attribute class melalui key dot(.) -> objek.attClass
# *  cara menghubungkan untuk attribute objek yang diambil dari kontrutktor adalah menyandingkan nama objek dengan attribute objek by self as pointer melalui key dot(.) -> objek.attObjekBySelfAsPointer

# %%
# area class
class Dog:
    # Class attribute
    species = "mammal"

    # Instance attribute
    def __init__(self, name):
        self.name = name

# area pemanggilan
# Object inisiasi through attribute objek
dog1 = Dog("Buddy")
dog2 = Dog("Charlie")

# mengakses attribute objek yang dikonversi ke objek
print("My name is {}".format(dog1.name)) #memanggil attribute objek(by konstruktor) dalam objek
print("My name is {}".format(dog2.name)) #memanggil attribute objek(by konstruktor) dalam objek

# mengakses attribute kelas as punya objek yang dikonversi ke objek
print("Dog1 is a {}".format(dog1.species))  #memanggil attribute kelas dalam objek
print("Dog2 is a {}".format(dog2.species)) #memanggil attribute kelas dalam objek
# Out:
# My name is Buddy
# My name is Charlie
# Dog1 is a mammal
# Dog2 is a mammal

# %% [markdown]
# ### bagaimana cara menghubungkan method ke objek?
# * lakukan pada area pemanggilan dengan bantuan keyword dot(.)

# %%
# area class
# area pemanggilan
print(objek.method())

# %% [markdown]
# ### Bagaimana penerapan recursif dalam suatu class dan objek

# %%
# dengan menerapkan class dan objek sbg template/konstruksi method recursif
class Factorial:
    def calculate(self, n):
        if n == 0:
            return 1
        else:
            return n * self.calculate(n - 1) # n = 5 * calculate method ngereturn n-1= 4 * calculate method ngereturn n-1= 3 * calculate method ngereturn n-1= 2 * calculate method ngereturn n-1= 1 * calculate method ngereturn n-1= 0



# Membuat objek dari kelas Factorial
fact = Factorial()

# Menghitung faktorial dari 5
result = fact.calculate(5)
print(result)
# Out:
# 120

# %%
# dengan menerapan contoh code linkedlist single
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None  # Referensi ke objek Node lain (self-referential)

    def add(self, value):
        if self.next is None:
            self.next = Node(value)  # Membuat objek Node baru
        else:
            self.next.add(value)  # Rekursi dengan memanggil method pada objek Node berikutnya

    def __str__(self):
        if self.next:
            return f"{self.value} -> {self.next}"
        else:
            return f"{self.value}"

# Membuat objek Node pertama
head = Node(1)
# Menambahkan node ke dalam linked list secara rekursif
head.add(2)
head.add(3)
head.add(4)

print(head)
# Out:
# 1 -> 2 -> 3 -> 4

# %% [markdown]
# # Property

# %% [markdown]
# # Self parameter dan konstruktor class

# %% [markdown]
# ### bagaimana saja cara menggunakan parameter self dalam konstruktor pada python?
# * self didefinisikan sebagai parameter pertama dalam konstruktor dan bisa juga dalam sebuah method.
# * init adalah konstruktor yang dimaksud dalam python OOP
# * baik dikonstruktor, maupun hanya dimehtod self adalah pointer untuk menyambungkan variabel objek dan variabel class ke objek.

# %%
class GFG:
    p = "manager" #attribute class
    def __init__(self, name, company): #consturktor yang menyimpan self parameter untuk attribute objek
        self.name = name
        self.company = company

    def show(self): #method display output self paraemter
        print("Hello my name is " + self.name+" and I" +
              " work in "+self.company+ "as" + self.p+".")


obj = GFG("John", "GeeksForGeeks")
obj.show()
# Out:
# Hello my name is John and I work in GeeksForGeeksasmanager.

# %% [markdown]
# ### Jika self adalah sebuah pointer yang menghubunkgan langsung dari konstruktor ke objek, buktikan! jika cls juga sbg pointer yang menhubungkan dari attribute class ke objeknya, buktikan!
# :
# Jadi intinya id itu adalah identitas uniq suatu data(variabel, method, class) sehingga untuk membuktikanya kita perlu cek id di area class termasuk var, method, dan class.

# %%
class Mahasiswa:
    attributeClass = " "
    @classmethod
    def uji_attClass(cls):
        print(f"id untuk method clas biasa: {id(cls.attributeClass)}")
    def __init__(self, nama, umur):
        self.nama = nama
        self.umur = umur
        print(f'ID self dalam __init__: {id(self)}')
        print(f'ID self untuk att nama: {id(self.nama)}')
        print(f'ID self untuk att umur: {id(self.umur)}')


    def tampilkan_informasi(self):
        print(f'ID self dalam method lanjutan: {id(self)}')

# Membuat objek dari kelas Mahasiswa
mahasiswa1 = Mahasiswa("Budi", 20)
print(f'ID Objek mahasiswa1: {id(mahasiswa1)}')
# Menampilkan informasi mahasiswa dan ID self
mahasiswa1.tampilkan_informasi()
Mahasiswa.uji_attClass()
print(f"Id untuk objek class ori {id(Mahasiswa.attributeClass)}")
# Out:
# ID self dalam __init__: 137230132491344
# ID self untuk att nama: 137230380915632
# ID self untuk att umur: 137230708400872
# ID Objek mahasiswa1: 137230132491344
# ID self dalam method lanjutan: 137230132491344
# id untuk method clas biasa: 137230708442664
# Id untuk objek class ori 137230708442664

# %% [markdown]
# ### Kenapa attribute yang disertai self tidak menunjukan value suatu data bertipe?
# * self kadang tidak memperlihatkan value secara langsung jika didefine dalam konstruktor. Namun, dia menyimpan secara implisit sebuah value yang diinisiasi dalam OBJEK oop karena setiap atribute self akan menjadi pointer ke objek tersebut.
# * bentuk attribute yang disertai self, tapi tidak menunjukan value suatu data bertipe ini tujuanya untuk flesibilitas code.
# * ada beberapa bentuk attribute dalam konstruktor yang eksplisit menyimpan value sebagai default. TUjuanya agar menaruh sebuah value tanpa didefine sebagai default valuenya.

# %%
class check:
    # perhatikan attribute ini lalu lihat bagian area pemanggilan

    # def __init__(self, pertama):
    #     self.pertama = pertama
    # def __init__(self, kedua):
    #     self.kedua = "kedua"
    # def __init__(self, ketigaHarusSama):
    #     self.bedaCoba = ketigaHarusSama
    # def __init__(self, keempat="test"):
    #     self.keempat = keempat
    def __init__(self):
        self.kelima = "test"
        # self.kelima = kelima #bisa dijadikan bukti bahwa jika kelima kiri tidak didefine sbg argumen constructor maka akan eror
#ini adalah cara memanggil attribute construktor class dalam suatu objek
# bentuk pertama
# maxs = "yeah"
# obj = check(maxs) #id construktor

#bentuk kedua
# obj = check("test") #jika hanya ini maka hasilnya akan berbentuk output mentah
# print(obj) #cek
# print(obj.kedua) #key kedua sebagai attribute yang bisa didefine diobjek karena dikaitkan oleh pointer self di atas

#bentuk ketiga
# obj = check("test")
# print(obj.bedaCoba)

#bentuk keempat
# obj = check()
# print(obj.keempat)

#bentuk kelima
obj = check()
print(obj.kelima)
# Out:
# test

# %% [markdown]
# # polymorphism in python

# %% [markdown]
# ### Bagaimana cara menerapkan polimorphsim di OOP secara umum?
# * simplenya kita punya banyak class yang memiliki method yang sama, tapi berbeda value outputnya
# * code dibawah ini adalah teknik yang normal, tapi kurang umum karena beberapa kekurangan

# %%
class India():
    def capital(self):
        print("New Delhi is the capital of India.")

    def language(self):
        print("Hindi is the most widely spoken language of India.")

    def type(self):
        print("India is a developing country.")

class USA():
    def capital(self):
        print("Washington, D.C. is the capital of USA.")

    def language(self):
        print("English is the primary language of USA.")

    def type(self):
        print("USA is a developed country.")


obj_ind = India()
obj_usa = USA()

obj_ind.capital()
obj_ind.language()
obj_ind.type()

obj_usa.capital()
obj_usa.language()
obj_usa.type()
# Out:
# New Delhi is the capital of India.
# Hindi is the most widely spoken language of India.
# India is a developing country.
# Washington, D.C. is the capital of USA.
# English is the primary language of USA.
# USA is a developed country.

# %% [markdown]
# ### Bagaimana penggunaan duck typing melalui polimorfisme?
# * sebelumnya kenali dulu apa itu duct typing, jadi dia itu punya definisi bahwa jika sesuatu itu mirip dengan bebek, kelakuanya mirip seperti bebek, karakteristiknya mirip kemungkinan itu adalah bebek.
# * perhatikan code dibawah, kita sumsikan analogi diatas, yaitu si bebek menjadi hewan/animal. Jika dia punya karakteristik seperti hewan, suara mirip hewan maka kemungkinan dia adalah hewan.

# %%
# versi OOP non-inheritance
class Dog:
    def characteristic(self):
        return "Anjing itu layaknya pemangsa daging dan pemakan bangkai, memiliki gigi tajam dan rahang yang kuat untuk menyerang, menggigit, dan mencabik-cabik makanan."

class Cat:
    def characteristic(self):
        return "dianggap sebagai karnivora yang sempurna dengan gigi dan saluran pencernaan yang khusus, suka mendengkur, kadang memijat babu!"

def cek_apakah_ini_hewan(animal): #method alat duck typing, jika dia punya characteristic mirip hewan, kemungkinan itu adalah hewan.
    print(animal.characteristic())

dog = Dog()
cat = Cat()

#ternyata setelah dicek, keduanya beneran hewan. Y gede.
cek_apakah_ini_hewan(dog)
cek_apakah_ini_hewan(cat)
# Out:
# Anjing itu layaknya pemangsa daging dan pemakan bangkai, memiliki gigi tajam dan rahang yang kuat untuk menyerang, menggigit, dan mencabik-cabik makanan.
# dianggap sebagai karnivora yang sempurna dengan gigi dan saluran pencernaan yang khusus, suka mendengkur, kadang memijat babu!

# %%
#  contoh lain
class India():
    def capital(self):
        print("New Delhi is the capital of India.")

    def language(self):
        print("Hindi is the most widely spoken language of India.")

    def type(self):
        print("India is a developing country.")

class USA():
    def capital(self):
        print("Washington, D.C. is the capital of USA.")

    def language(self):
        print("English is the primary language of USA.")

    def type(self):
        print("USA is a developed country.")

def func(obj):
    obj.capital()
    obj.language()
    obj.type()

obj_ind = India()
obj_usa = USA()

func(obj_ind)
func(obj_usa)

# %%
# contoh oop with ducktyping dnegan inheritance
class Animal:
    def speak(self):
        raise NotImplementedError("Subclass must implement this method")

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

# Create a list of Animal objects
animals = [Dog(), Cat()]

# Call the speak method on each object
for animal in animals:
    print(animal.speak())

# %% [markdown]
# ### penggunaan abstrak method pada polimorfisme
# * import dulu package abc, modul ABC, key abstractmethod, dan @abstractmethod.
# * jadikan abc sbg input layaknya inheritance terhadap ABC class lalu define class dan method yang akan di polimorfisme.
# * ABC (Abstract Base Classes) module adalah bagian dari library standar Python yang menyediakan kerangka dasar untuk mendefinisikan kelas abstrak. Kelas abstrak adalah kelas yang tidak dimaksudkan untuk diinstansiasi secara langsung, tetapi dirancang untuk menjadi basis bagi kelas lain. Kelas ini bisa berisi metode abstrak, yang harus diimplementasikan oleh subclass.
# * *Dekorator abstractmethod digunakan untuk menandai metode sebagai abstrak. Metode abstrak adalah metode yang dideklarasikan di kelas abstrak tetapi tidak memiliki implementasi. Subclass dari kelas abstrak ini harus mengimplementasikan metode abstrak ini, jika tidak, Python akan memunculkan kesalahan TypeError.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        # pass
        return NotImplemented

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

animals = [Dog(), Cat()]
for animal in animals:
    print(animal.sound())
# Out:
# Bark
# Meow

# %%
# jika @abstractmethod tidak digunakan untuk polimorfisme
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        # pass
        return NotImplemented

class Dog(Animal):
    def non(self):
        return "Bark"

class Cat(Animal):
    def non(self):
        return "Meow"

animals = [Dog(), Cat()]
for animal in animals:
    print(animal.sound())

# %% [markdown]
# ### bagaimana implementasi polimorfisme dengan inheritance class?
# * bisa dilakukan dengan membuat semacam class utama/parent, lalu sub class/child akan mengoverride method di class utama, tapi yang dipanggil hanya si child class saja.
# * pemanggilan bisa melalui konsep duck typing yang sedikit berbeda jika dengan inheritance. jadi terdapat bantuan objek list yang mengandung class kemudian dilanjutkan dengan iterasi pemanggilan objek yang tersambung dengan method layaknya konsep duck typing satunya

# %%
# bentuk sederhana
class Animal:
    def speak(self):
        raise NotImplementedError("Subclass must implement this method")

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

# Create a list of Animal objects
animals = [Dog(), Cat()]

# Call the speak method on each object
for animal in animals:
    print(animal.speak())
# Out:
# Woof!
# Meow!

# %% [markdown]
# ### Bagaimana implementasi dan maksud dari overidding pada polymorphism?
# * overriding itu artinya apabila suatu method dalam kelas utama memiliki suatu method kemudian terjadi polimorphisme terhadap sub class sehingga method tadi juga dimiliki oleh dia, value yang dihasilkan jika panggil dalam objek adalah si value method yang didefine pada sub class

# %%
class Animal:
    def sound(self):
        return "Some sound"

class Dog(Animal):
    def sound(self):
        return "MIHAW"

dog = Dog()
print(dog.sound())
# Out:
# MIHAW

# %% [markdown]
# # Inheritance

# %% [markdown]
# ##  Apa saja yang elemen yang bisa diturunkan!(attribute class, attribute object, method, constructor)
# * Semua elemen yang dimaksud diatas, bisa diwariskan dari kelas utama/kelas bagian
# * Artinya semua elemen tersebut bisa dipanggil dari kelas childnya.

# %%
class Person(object):
# attribute class
    status = "man"
    @classmethod
    def punya(cls):
        return cls.status
# Constructor
    def __init__(self, name):
        self.name = name
#method objek
    def getName(self):
        return self.name
    def isEmployee(self):
        return False

class Employee(Person):
# constructor inher
    def __init__(self, name, idnumber, salary, derived):
        self.salary = salary
        self.derived = derived
        Person.__init__(self, name) #isi paremeter sesuai dengan attribute yang ada di class parent.

# method objek inher
    def getSalary(self):
        return self.salary
    def getDerived(self):
        return self.derived
    def isEmployee(self):
        return True
# attribute class dan @classmethod inheritance
    @classmethod
    def punya1(cls):
        cls.status = "girl"
        return cls.status


# area pemanggilan
# mencoba yang inheritance normal (objek anak memanggil properti parent)
emp2 = Employee("Geek2", 1234, 5000, "maroko")  # An Object of child
print(emp2.getName())
print(emp2.isEmployee())
print(emp2.punya())
# Out:
# Geek2
# True
# man

# %% [markdown]
# ## Apa keyword fungsi 'object' yang kadang ada pada sebuah main class?
# * object pada value class person adalah represnetasi dari New-style class yang merupakan akar dari semua kelas di Python yang memberikan metode dan properti dasar yang dibutuhkan semua objek. Ini muncul pada jaman python 2.2.
# * tujuanya untuk menyediakan super() dan sebagai deskriptor(kemudahan dalam mengakses class di class lain dengan semua class diisi value : "object")
# * sebetulnya sekarang pada python 3. si  New-style class ini tidak perlu didefine secara eksplisit karena sudah otomatis.

# %%
class Person(object):
    def __init__(self, name="esteh", idnumber="maung"):
        self.name = name
        self.idnumber = idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)
class melu(object):
    descriptor = Person() #ini dia

class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        super(Employee, self).__init__(name, idnumber)
        self.salary = salary
        self.post = post

    def display(self):
        super(Employee, self).display()
        print(self.salary)
        print(self.post)

# creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using its instance
a.display()
obj = melu()
obj.descriptor = "mariana"
print(obj.descriptor)
# Out:
# Rahul
# 886012
# 200000
# Intern
# mariana

# %% [markdown]
# ## apakah benar  inheritance tidak hanya berlaku pada main class saja, tetapi juga untuk sub class?
# * : benar, tidak hanya main class saja yang dapat menggunakan inheritance, tapi juga untuk sub class ke anakanya. Artinya child-parent bersifat ragam.
# * jika subclass menurunkan anaknya, parent dari subclass tersebut akan diwarisi sifatnya ke anaknya.
# * Gampangnya cucu dia entah ke 1 atau sampai n.

# %%
class A:
    def __init__(self, n):
        self.name = n
# inherotance(parent-child)
class B(A):
    def __init__(self, n='Rahul', umur= 16):
        self.umur = umur
        A.__init__(self, n)
    def tambah_att(self):
        print(self.name, self.umur)
# inheritance (old parent-parent-child)
class C(B):
    def __init__(self, asal, n='Rahul', umur= 16):
        self.asal = asal
        B.__init__(self, n, umur)
    def tambah_att2(self):
        print(self.name, self.asal, self.umur)

object = C("bandung")
object.tambah_att2()
# Out:
# Rahul bandung 16

# %% [markdown]
# ## bagaimana perbedaan penggunaan metode superclass dengan pemanggilan super() dan pemanggilan langsung
# * pemakaian ururtan yang sesuai dengan MRO
# 1. Dalam menggunakan super() dalam code inheritance, kita bisa mengikuti prinsip MRO python. MRO adalah urutan di mana Python mencari metode dan atribut dalam hierarki kelas. super() menggunakanya sehingga membantu secara otomatis dengan hanya satu bentuk dalam yang sama, sedangkan pemanggilan class x constructor harus diatur secara manual dengan memperhatikan ketelitian class mana yang harus diinisialisasi terlebih dahulu(urutan).
# 2. Jika menggunakan class x constructor maka akan muncullebih banyak code yang di pakai karena harus menginisialisasi setiap kelas dasar di kelas lain sehingga kurang simple. sementara, dengan super Kode lebih bersih, lebih konsisten, dan lebih mudah untuk dipelihara.
# 3. menggunakan class x constructor akan berpotensi untuk panggilan duplikat atau pengabaian panggilan meningkat, terutama dalam pewarisan ganda. Beda jika menggunakan super() yang akan Menyederhanakan pewarisan ganda dengan memastikan bahwa setiap kelas dasar diinisialisasi dengan benar tanpa duplikasi. (kurang pembuktian)

# %%
# pure super()
class Person():
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def display(self):
    print(self.name, self.age)

# child class
class Student(Person):
  def __init__(self, name, age):
    self.sName = name
    self.sAge = age
    # inheriting the properties of parent class
    super().__init__("Rahul", age)

  def displayInfo(self):
    print(self.sName, self.sAge)


obj = Student("Mayank", 23)
obj.display()
obj.displayInfo()
# Out:
# Rahul 23
# Mayank 23

# %%
# pure code pemanggilan construktor kelas induk
class A:
    def __init__(self, n='Rahul'):
        self.name = n

class B(A):
    def __init__(self, roll, n):
        self.roll = roll
        A.__init__(self, n) #dengan argumen, kita bisa mereturn objek sebelumnya, misal self.name di dalam constructor atau method lain
        print('Name:', self.name)
        print('Roll:', self.roll)

        # A.__init__(self) # tanpa argumen lain dari kelas sebelumnya, artinya dia hanya bisa mereturn objek sebelumnya, misal self.name
        # print('Name:', self.name)
        # print('Roll:', self.roll)

object = B(23, 'Raju')
print(object.name) #inilah yang membedakan antara penggunaan inheritance + pemanggilan constructor dengan inheritance tanap itu
# Out:
# Name: Raju
# Roll: 23
# Raju

# %%
# contoh penggunaan super() di beberapa kasus
class Base1(object):
    def __init__(self):
        super().__init__()  # Call the next class in the MRO
        self.str1 = "A's __init__" #jika ingin urut dan lebih mudah dipahami
        p = "A's __init__" #urut bisa, tapi kurang mudah dipahami
        print(p)


class Base2(object):
    def __init__(self):
        super().__init__()  # Call the next class in the MRO
        self.str2 = "B's __init__"
        q = "B's __init__"
        print(q)


class Derived(Base1, Base2): #variabel non self, bisa urut ketika dicustom di sini
    def __init__(self):
        super().__init__()  # Call the next class in the MRO
        s = "C's __init__"
        print(s)
        self.str3 = "C's __init__"
        print(self.str1, self.str2, self.str3)



ob = Derived()
# Out:
# B's __init__
# A's __init__
# C's __init__
# A's __init__ B's __init__ C's __init__

# %%
# kasus jika inheritance yang dipakai begitu kompleks, saran menggunakan super() + *kwargs + OPSIONAL=kombinasi pemanggilan konstruktor kelas induk
class base():
    def __init__(self, **kwargs):
        pass

class Base1(base):
    def __init__(self, str1, **kwargs):
        super().__init__(**kwargs)
        self.str1 = str1

class Base2(base):
    def __init__(self, str2, **kwargs):
        super().__init__(**kwargs)
        self.str2 = str2

class Base3(base):
    def __init__(self, str3, **kwargs):
        super().__init__(**kwargs)
        self.str3 = str3

class Derived(Base1, Base2, Base3):
    def __init__(self, str1, str2, str3, str4, **kwargs):
        super().__init__(str1=str1, str2=str2, str3=str3, **kwargs)
        self.str4 = str4

    def printStrs(self):
        print(self.str1, self.str2, self.str3, self.str4)

ob = Derived("A", "B", "C", "D")
ob.printStrs()
# Out:
# A B C D

# %% [markdown]
# ## Apa perbedaan inheritance biasa dengan inheritance yang menggunakan pemanggilan constructor atau super()?
# * Inheritance Biasa:
# 1. Atribut dan metode dari kelas dasar diwariskan, tetapi konstruktor kelas dasar tidak dipanggil otomatis.
# 2. Atribut yang diinisialisasi dalam konstruktor kelas dasar tidak tersedia kecuali konstruktor dipanggil secara eksplisit.
# 3.

# %%
class Base:
    def __init__(self):
        self.base_attribute = "Base Attribute"

class Derived(Base):
    def __init__(self):
        # Konstruktor kelas dasar tidak dipanggil
        self.derived_attribute = "Derived Attribute"

obj = Derived()
print(obj.derived_attribute)  # Output: Derived Attribute
print(obj.base_attribute)     # Akan menghasilkan error karena base_attribute tidak diinisialisasi
                                # lebih ke arah ouput sih sebenarnya, kalo pakai super() atau pemanggilan constructor induk maka bisa
# Out:
# Derived Attribute
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 12
#      10 obj = Derived()
#      11 print(obj.derived_attribute)  # Output: Derived Attribute
# ---> 12 print(obj.base_attribute)     # Akan menghasilkan error karena base_attribute tidak diinisialisasi
#
# AttributeError: 'Derived' object has no attribute 'base_attribute'

# %% [markdown]
# ## jika dalam java hanya ada satu warisan, bagaimana dengan python?
# * python memiliki 5 jenis pewarisan umum dan 1 jenis penspesifikasian
# * inheritance single = satu kelas turunan dari kelas lain
# * inheritance multiple = kelas turunan dari dua kelas lain
# * inheritance multilevel = kelas turunan dari kelas turunan lain
# * inheritance heirarchical = kelas turunan dari kelas yang sama
# * inheritance hybrid = kombinasi dari semua jenis pewarisan di atas
# * inheritance diamond as spesifikasi hybrid/kombinasi heirarchical dan multilevel= kombinasi dari inheritance heirarchical dan multilevel yng bisa jg disebut hybrid agak laen

# %% [markdown]
# * code dibawah adalah beberapa contoh yang mendapat pengecualian dalam hal catatan karena ada tambahan dengan mengulik code tersebut. Bukan berarti yang tidak ada bisa disebut tidak diulik, melainkan bisa jadi sudah paham, belum kepikiran, atau nge-hold dulu karena stuck.
# * untuk versi lengkap akan ada di: https://www.geeksforgeeks.org/types-of-inheritance-python/

# %%
# Multilevel Inheritance
class Grandfather:
    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINISAISI DARI INPUT USER DI OBJEK
    # def __init__(self, grandfathername):
    #     self.grandfathername = grandfathername

    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINIASI DARI DALAM CLASS
    def test(self):
        p = "Test"
        return p

# Intermediate class
class Father(Grandfather):
    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINISAISI DARI INPUT USER DI OBJEK
    # def __init__(self, fathername, grandfathername):
    #     self.fathername = fathername

    #     # invoking constructor of Grandfather class
    #     Grandfather.__init__(self, grandfathername)

    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINIASI DARI DALAM CLASS
    def test2(self):
        s = "beredum"
        Grandfather.test(self)
        # print(s + self.test())
        return s + self.test()

#DERIVED CLASS
class Son(Father):
    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINISAISI DARI INPUT USER DI OBJEK
    # def __init__(self, sonname, fathername):
    #     self.sonname = sonname

    #     # invoking constructor of Father class
    #     Father.__init__(self, fathername)

    # def print_name(self):
    #     print('Grandfather name :', self.grandfathername)
    #     print("Father name :", self.fathername)
    #     print("Son name :", self.sonname)

    #TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINIASI DARI DALAM CLASS
    def test3(self):
        n = "cuk"
        Father.test2(self)
        return n + self.test2()

    def print_name(self):
        print('Grandfather name :', self.test())
        print("Father name :", self.test2())
        print("Son name :", self.test3())


#TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINISAISI DARI INPUT USER DI OBJEK
# s1 = Son('Prince', 'Rampal', 'Lal mani')
# s1.print_name()


#TUJUAN KETIKA LU MAU OBJEK YANG DIHASILKAN ITU DIINIASI DARI DALAM CLASS
s1 = Son()
s1.print_name()
# Out:
# Grandfather name : Test
# Father name : beredumTest
# Son name : cukberedumTest

# %%
class A:
    def __init__(self, n):
        self.name = n
# inherotance(parent-child)
class B(A):
    def __init__(self, umur):
        self.umur = umur
        A.__init__(self, n='Rahul')
    def tambah_att(self):
        print(self.name, self.umur)
# inheritance (old parent-parent-child)
class C(B):
    def __init__(self, asal):
        self.asal = asal
        B.__init__(self, n, umur)
    def tambah_att2(self):
        print(self.name, self.asal)
# inheritance (old parent - cicit)
class D(A): #apakah kalo begini bisa loncat sifat inheritance hanya pada B tanpa ada kaitanya dengan C?
    def __init__(self, nama):
        self.nama = nama
        A.__init__(self, n, umur)
    def tambah_att3(self):
        print(self.name, self.nama)
# inheritance (mbah buyut - mbah - cucu))
class E(B):
    def __init__(self, nama):
        self.nama = nama
        B.__init__(self, n, umur)
    def tambah_att4(self):
        print(self.name, self.nama)

# object = B(23)
# memanggil dari POV objek A
object = D()
object.name
object.tambah_att()
# memanggil dari POV objek B
object = B()
object.name
object.tambah_att()
# Out:
# Rahul 23

# %% [markdown]
# # Data Hiding
# catatan: <br>
# 1. Meng-private di python hanya untuk variabel dan method saja.
# 2. cara ngeprivate hanya dapat dilakukan dengan menambah doble undescore di sebelum/diawal nama variabel dan method. Jika anda menambahkan code di belakang keduanya maka tidak akan works.
# 3. Cara paksa akses variabel dan method yang udha kena hiding adalah dengan menuliskan '_namaclass__namavariabel' atau '_namaclass__namamethod'

# %% [markdown]
# ## Private attribute suatu class, bagaimana caranya?
# Gunakan doble underscores pada awal variabel. misal: __d, __a. Nantinya setelah kita mencoba mengakses variabel __d atau __a di kelas child pada objeknya, variabel tersebut akan berubah menjadi _ClassName__variableName -> _C__d atau _C__a. Sementara itu, class D tidak punya kedua variabel diatas yang sudah berganti nama. Jika diakes, hasilnya akan AttributeError

# %%
class Product:
    def __init__(self):
        self.data1 = 10
        self.__data2 = 20 #contoh bentuk 1 sbg ciri-ciri att private
    def methodA(self):
        pass
    def __methodB(self):
        pass
p = Product()
print(p.data1)
# print(p.__data2)
print(p._Product__data2)
p.methodA()
# p.__methodB()
# dir(p)
# p._Product__methodB()
# Out:
# 10
# 20

# %%
class Book:

    def __init__(self,isbn, title,author,publisher,pages,price,copies):
        self.isbn = isbn
        self.title = title
        self.author = author
        self.publisher = publisher
        self.pages = pages
        self.__price = price
        self.copies = copies

    def display(self):
        print(self.title)
        print(f'ISBN : {self.isbn}')
        print(f'Price : {self.__price}')
        print(f'Number of copies : {self.copies}')
        print('.' * 50)
# book1 = Book('957-4-36-547417-1', 'Learn Physics','Stephen', 'CBC', 350, 200,10)
# book2 = Book('652-6-86-748413-3', 'Learn Chemistry','Jack', 'CBC', 400, 220,20)
# book3 = Book('957-7-39-347216-2', 'Learn Maths','John', 'XYZ', 500, 300,5)
# book4 = Book('957-7-39-347216-2', 'Learn Biology','Jack', 'XYZ', 400, 200,6)

# book1.display()
# book2.display()
# book3.display()
# book4.display()

# %%
# pembuktian kedua hiding data
print(book1.price)
# Out:
# ---------------------------------------------------------------------------
#
#
#
# AttributeError                            Traceback (most recent call last)
#
#
#
# Cell In[24], line 1
#
#
#
# ----> 1 print(book1.price)
#
#
#
#
#
#
#
# AttributeError: 'Book' object has no attribute 'price'

# %% [markdown]
# ## QNA for data hiding
# 1. Apakah data hiding dalam sebuah method dan variabel hanya berlaku di oop saja? apakah di porsedural tidak bisa?
# : ya benar, karena data hiding erat kaitanya dengan menyembunyikan method atau variabel internal agar tidak dapat diakses kepada user(eksternal). Di dalam pemrograman prosedural, konsep data hiding tidak diimplementasikan dengan cara yang sama karena pendekatan ini tidak memiliki struktur class dan objek seperti pada OOP. Pemrograman prosedural lebih berfokus pada urutan eksekusi fungsi dan penggunaan variabel global atau lokal, tanpa ada mekanisme bawaan untuk menyembunyikan data secara langsung dari bagian lain dari program. Data hiding bisa diakalin dengan membuat variabel lokal dan global dalam sebuah method, tapi itu masih terbilang bukan yang dimaksud data hiding secara asli.

# %%
# contoh dia ga bisa
def __methodB(self):
        return self
p = __methodB(10)
__p = 10
print(p + __p)
# Out:
# 20

# %% [markdown]
# # Property?
# * Property memungkinkan akses ke attribute objek melalui method, bahkan jika method tersebut tidak dipanggil dengan menggunakan tanda kurung. Dengan kata lain, property memungkinkan untuk mengakses atau memodifikasi atribut sebuah objek seperti mengakses atribut biasa, padahal sebenarnya itu menggunakan method.
# * Dekorator Property:
# 1. @property: Diletakkan di atas metode yang berfungsi sebagai getter. Ini mengubah metode tersebut menjadi sebuah property yang dapat diakses tanpa tanda kurung.
# 2. @name.setter: Diletakkan di atas metode yang berfungsi sebagai setter. Ini memungkinkan kita menetapkan nilai baru untuk property.
# 3. @name.deleter: Diletakkan di atas metode yang berfungsi sebagai deleter. Ini memungkinkan kita menghapus property.
# * Kegunaan Property:
# 1. Pengecekan dan Validasi Tipe Atribut: Property dapat digunakan untuk memeriksa tipe data atau validasi saat sebuah nilai diberikan ke atribut.
# 2. Membuat Atribut Hanya-Baca atau Hanya-Tulis: Dengan property, kita bisa membuat atribut yang hanya bisa dibaca (read-only) atau hanya bisa diisi (write-only).
# 3. Mengubah Variabel Instans Menjadi Atribut yang Dihitung Secara Dinamis: Property memungkinkan sebuah atribut menjadi hasil dari suatu perhitungan yang dilakukan saat atribut tersebut diakses.
# 4. Menambahkan Perilaku Baru Tanpa Mengubah Kode Klien: Dengan menggunakan property, kita bisa menambahkan perilaku baru pada variabel instans tanpa harus mengubah kode yang sudah ada yang menggunakan variabel tersebut.

# %% [markdown]
# * QNA
# apakah syntax untuk cara pakai si @name.setter hanya kayak self.var_hiding = var_new doang gitu?
# keknya gw perlu cari tau asal usul tu property biar paham variasi penggunaanya.

# %% [markdown]
# ### Membuktikan the power of @property secara sederhana

# %%
class product:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    # def display(self):
    #     print(self.__x)
    # def value(self):
    #     return self.__x
    @property
    def display(self):
        print(self.__x)
    @property
    def value(self):
        return self.__x
    @value.setter
    def value(self, x):
        self.__x = x

    #cod ini buat: percobaan jika kita lakukan assign value, tapi hanya dengan @property saja:
    # @property
    # def value(self, x):
    #     self.__x = x
    # def value(self):
    #     return self.__x
p = product(12, 24)
print('---Output tanpa @property---')
print("2 variasi so far: ")
# p.display()
# #variasi pertama karena cuma return langsung print tanpa harus di print lagi
# p.value()
# #variasi kedua return + print and works

print("percobaan jika kita lakukan operasi: ")
# print(p.value() + 5)
# #terapkan pada variasi kedua karena dia return nilai, ternyata works
print("percobaan jika kita lakukan assign value: ")
# p.value() = 17
# #percobaan dengan variasi kedua, eror
# print(p.value())
# #hasilnya gagal
# n = p.value()
# n = 15
# #jika dibuat begini kenapa bisa?
# print(n)
# #karena variabel n adalah variabel baru yang tidak ada hubungan samsek dengan class dan dia diatas menyimpan value dari return. Artinya kalopunvalue yang disimpan bukan dari pemanggilan objek variabel tetap bisa berjalan.
# c = 12
# c = 13
# print(c)
# #logikanya mirip kek gini
print('---Output dengan @property---')
print("2 variasi so far: ")
p.display
#inilah yang dimaksud dan sesuai dengan parsial dalam definisi @property dan in ivariasi pertama
print(p.value)
#variasi kedua
print("percobaan jika kita lakukan operasi: ")
print(p.value + 5)
#varisi bila ingin percobaan
print("percobaan jika kita lakukan assign value, tapi hanya dengan @property saja: ")
# p.value = 11
# #hasilnya akan eror ga karuan kayak butuh inisasi value, tapi kan dia diubah pakai @property jadi bukan method, harus pakai @ tambahan, yakni @name.setter
# print(p.value)
print("percobaan jika kita lakukan assign value dengan setter: ")
p.value = 11
#aman terkendali
print(p.value)
#hasilnya udh berubah deh
print("percobaan jika kita mencoba pakai @property tapi ada () dibawah: ") #hasilnya akan eror
print(p.value())
#hasilnya eror karena dia itu bukan method lagi melainkan attribute
# Out:
# ---Output tanpa @property---
# 2 variasi so far:
# percobaan jika kita lakukan operasi:
# percobaan jika kita lakukan assign value:
# ---Output dengan @property---
# 2 variasi so far:
# 12
# 12
# percobaan jika kita lakukan operasi:
# 17
# percobaan jika kita lakukan assign value, tapi hanya dengan @property saja:
# percobaan jika kita lakukan assign value dengan setter:
# 11
# percobaan jika kita mencoba pakai @property tapi ada () dibawah:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[10], line 56
#
#      54 print(p.value) #hasilnya udh berubah deh
#
#      55 print("percobaan jika kita mencoba pakai @property tapi ada () dibawah: ") #hasilnya akan eror
#
# ---> 56 print(p.value())
#
#
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### Menggunakan 3 jenis dekorator property

# %%
class Person:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        if not isinstance(value, str):
            raise ValueError("Name must be a string") #salah satu cara jika lu pingin mengakali suatu sistem
        self._name = value

    @name.deleter
    def name(self):
        print("Deleting name...")
        del self._name

# Contoh penggunaan
p = Person("Alice")
print(p.name)  # Output: Alice

p.name = "Bob"
print(p.name)  # Output: Bob

del p.name  # Akan memanggil deleter dan menghapus atribut _name
# Output: Deleting name...

# print(p.name)
# Jika mencoba mengakses p.name setelah penghapusan, akan muncul AttributeError: 'Person' object has no attribute '_name'

#untuk itu coba ini:
try:
    print(p.name)
except AttributeError:
    print("Name attribute has been deleted")
# Out:
# Alice
# Bob
# Deleting name...
# Name attribute has been deleted

# %% [markdown]
# ### Contoh beberapa kegunaan @property

# %% [markdown]
# **Pengecekan dan Validasi Tipe Atribut**

# %%
class Person:
    def __init__(self, name):
        self._name = name

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        if not isinstance(value, str):
            raise ValueError("Name must be a string")
        self._name = value

# Contoh penggunaan
p = Person("Alice")
print(p.name)  # Output: Alice

p.name = "Bob"  # Tidak ada masalah
print(p.name)  # Output: Bob

p.name = 123  # Akan memunculkan ValueError: Name must be a string
# Out:
# Alice
# Bob
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[11], line 22
#
#      19 p.name = "Bob"  # Tidak ada masalah
#
#      20 print(p.name)  # Output: Bob
#
# ---> 22 p.name = 123  # Akan memunculkan ValueError: Name must be a string
#
#
#
# Cell In[11], line 12, in Person.name(self, value)
#
#       9 @name.setter
#
#      10 def name(self, value):
#
#      11     if not isinstance(value, str):
#
# ---> 12         raise ValueError("Name must be a string")
#
#      13     self._name = value
#
#
#
# ValueError: Name must be a string

# %% [markdown]
# **Membuat Atribut Hanya-Baca atau Hanya-Tulis**

# %%
# Hanya bisa baca
class Circle:
    def __init__(self, radius):
        self._radius = radius

    @property
    def radius(self):
        return self._radius


# Contoh penggunaan
c = Circle(5)
print(c.radius)  # Output: 5

c.radius = 10  # Akan memunculkan AttributeError: can't set attribute
# Out:
# 5
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[9], line 15
#
#      12 c = Circle(5)
#
#      13 print(c.radius)  # Output: 5
#
# ---> 15 c.radius = 10  # Akan memunculkan AttributeError: can't set attribute
#
#
#
# AttributeError: property 'radius' of 'Circle' object has no setter

# %%
# write only
class PasswordManager:
    def __init__(self):
        self._password = None

    @property
    def password(self):
        raise AttributeError("Password is write-only")

    @password.setter
    def password(self, value):
        self._password = value

# Contoh penggunaan
pm = PasswordManager()
pm.password = "securepassword"  # Tidak ada masalah

print(pm.password)  # Akan memunculkan AttributeError: Password is write-only
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[10], line 18
#
#      15 pm = PasswordManager()
#
#      16 pm.password = "securepassword"  # Tidak ada masalah
#
# ---> 18 print(pm.password)  # Akan memunculkan AttributeError: Password is write-only
#
#
#
# Cell In[10], line 8, in PasswordManager.password(self)
#
#       6 @property
#
#       7 def password(self):
#
# ----> 8     raise AttributeError("Password is write-only")
#
#
#
# AttributeError: Password is write-only

# %% [markdown]
# **Mengubah Variabel Instans Menjadi Atribut yang Dihitung Secara Dinamis:**

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    @property
    def area(self):
        return self.width * self.height

# Contoh penggunaan
r = Rectangle(4, 5)
print(r.area)  # Output: 20

r.width = 6
print(r.area)  # Output: 30, area berubah sesuai perubahan width
# Out:
# 20
# 30

# %% [markdown]
# **Menambahkan Perilaku Baru Tanpa Mengubah Kode Klien:**

# %%
class Employee:
    def __init__(self, name, salary):
        self._name = name
        self._salary = salary #anggap ini sebuah variabel untuk salary yang tersembunyi dari user

    @property
    def salary(self): #dengan adanya method + @property, salary bisa diakses user value attributnya
        return self._salary

    @salary.setter #ini juga membuat salary bisa diubah/diedit oleh user, tapi bisa tetap di atur sistemnya biar tidak bias
    def salary(self, value):
        if value < 0:
            raise ValueError("Salary cannot be negative")
        self._salary = value

# Contoh penggunaan
e = Employee("John", 5000)
print(e.salary)  # Output: 5000

e.salary = 6000  # Tidak ada masalah
print(e.salary)  # Output: 6000

e.salary = -100  # Akan memunculkan ValueError: Salary cannot be negative
# Out:
# 5000

# %% [markdown]
# **Alasan kenapa @property bisa lebih baik dipakai daripada variabel objek**

# %%
# before
# class Product():
#     def __init__(self, id, marked_price):
#         self.id = id
#         self.marked_price = marked_price
#         self.selling_price = self.marked_price - 0.01 * self.marked_price


#     def discount(self):
#         return self.marked_price+2 if self.marked_price > 500 else self.marked_price

# #inisiasi value objek
# p4 = Product('H456', 800)
# print(p4.marked_price) #800
# print(p4.discount()) #802
# print(p4.selling_price) #792
# p4.marked_price = 20
# print(p4.discount()) #padahal si diskon berubah = 20
# print(p4.selling_price) #kok tetep sama = 792


# after
class Product():
    def __init__(self, id, marked_price):
        self.id = id
        self.marked_price = marked_price
    @property
    def selling_price(self):
        return self.marked_price - 0.01 * self.marked_price
    def discount(self):
        return self.marked_price+2 if self.marked_price > 500 else self.marked_price

p4 = Product('H456', 800)
print(p4.marked_price) #800
print(p4.discount()) #802
print(p4.selling_price) #792
p4.marked_price = 20
print(p4.discount()) #si diskon berubah = 20
print(p4.selling_price) #jadi berubah = 19.8
# Out:
# 800
# 802
# 792.0
# 20
# 19.8

# %% [markdown]
# ## cara untuk mengakses variabel private bagaimana?
# * pertama buat sebuah method konstruktor atau method class diclass utama, lalu coba return.
# * di class berikutnya  dan di area pemanggilan variabel private tersebut dapat digunakan

# %%
class C(object):
    __a = 22
    def __init__(self):
        self.c = 21
        self.__d = 42
    def coba(self):     #rugi apabila seorang programmer mendefine
        return self.__d
    @classmethod
    def okGas(cls):
        return cls.__a

class D(C):
    def __init__(self):
        self.e = 84
        C.__init__(self)
    # def test(self):
    #     return self.__d
    # @classmethod
    # def cless(cls):
    #     return cls.__a
object1 = C()
object2 = D()
# akses variabel private dalam kelas parent/sendiri
# print(object1.__d) non Works
# print(object1.__a) non Works
# print(object1.c) #Works
# print(object1.coba()) #Works
# print(object2.okGas()) #Works

#akses variabel private dalam kelas child/luar
print(object2.test()) #non Works
# print(object2.cless()) non Works
# print(object2.__d)
# print(object2.__a)
# print(object2.c) #Works
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 31
#      22 object2 = D()
#      23 # akses variabel private dalam kelas parent/sendiri
#      24 # print(object1.__d) non Works
#      25 # print(object1.__a) non Works
#    (...)
#      29
#      30 #akses variabel private dalam kelas child/luar
# ---> 31 print(object2.test()) #non Works
#      32 # print(object2.cless()) non Works
#      33 # print(object2.__d)
#      34 # print(object2.__a)
#      35 # print(object2.c) #Works
#
# AttributeError: 'D' object has no attribute 'test'

# %% [markdown]
# # Abstract class
# * Intinya kelas abstrak layaknya blueprint as template, tapi tidak boleh dipakai alias hanya untuk di lihat atau dicopy/diduplikat ke dalam kelas lain.
# * Tidak hanya dalam bentuk class, tapi juga bisa direpresentasikan melalui method @abstractmethod. Method tersebut dioveride oleh sub kelas yang menjadi anak base kelas.
# * variasi cara merepresentasikanya bermacam-macam. silahkan cek link di bawah untuk selengkapnya

# %% [markdown]
# * resource: https://www.geeksforgeeks.org/abstract-classes-in-python/

# %% [markdown]
# **qna**
# 1. apakah maksud dari abstract class itu kayak lu punya cetak biru, tapi lu ga perlu manggil/menginsert blue print pada pengaplikasianya gitu?
# : kurang lebih gitu
# 2. yang contoh implementasi abstrak melalui subkelas, bisa cuma insert import abc aja? otomatis si python bakalan udh langsung paham kalo yang ada di kelas dasar adalah abstract class?
# :
# 3. Efek samping dari penggunaan subkelas langsung adalah, Anda dapat menemukan semua implementasi plugin Anda dengan menanyakan kelas dasar daftar kelas yang diketahui yang diturunkan darinya. maksudnya?
# 4. Bagaimana cara mengakses/melihat kelas dasar/base class yang dijadikan template

# %% [markdown]
# **salah satu contoh simple dan unik dari abstract class dimana cukup lakukan import library saja**

# %%
import abc

class parent:
    def geeks(self):
        pass

class child(parent):
    def geeks(self):
        print("child class")

# Driver code
print( issubclass(child, parent))
print( isinstance(child(), parent))
p = child()
p.geeks()
# Out:
# True
# True
# child class

# %% [markdown]
# ## pembuktian kalau lu panggil kelas base bakalan eror

# %%
# Python program showing
# abstract class cannot
# be an instantiation
from abc import ABC,abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
        pass
class Human(Animal):
    def move(self):
        print("I can walk and run")

class Snake(Animal):
    def move(self):
        print("I can crawl")

class Dog(Animal):
    def move(self):
        print("I can bark")

class Lion(Animal):
    def move(self):
        print("I can roar")

c=Animal()

# %% [markdown]
# ## cara mengakali jika ingin melihat class abstract
# ya dengan super()

# %%
# Python program invoking a
# method using super()
from abc import ABC

class R(ABC):
    def rk(self):
        print("Abstract Base Class")

class K(R):
    def rk(self):
        super().rk()
        print("subclass ")

# Driver code
r = K()
r.rk()

# %% [markdown]
# # Encapsulation in Python
# * Enkapsulasi: ini adalah konsep bagaimana sebuah data dalam sebuah pembungkus/kelas yang berisi variabel dan method. Data di dalamnya dapat dieksplisitkan dengan beberapa cara, tapi ciri khas dia itu kurang lebih ada 2 cara.
# * cara pertama: private member. mirip dengan konsep data hiding sih biar ga bisa diakses di luar kelas
# * cara kedua: protected member. intinya dia digunakan untuk kebutuhan internal kelas dasar mapun sub kelas/turunanya, tapi juga bsia diakses dari luar. Hanya saja cara kedua ini menunjukan bahwa akses data disepakati bersama oleh pengembang sebagai penanda bahwa seharusnya diperlakukan dengan hati-hati atau hanya digunakan dalam konteks tertentu (seperti dalam subkelas). Bisa diakses jika diperlukan saja sehingga membatasi dengan tetap memberikan flesibilitas.
# * sc dokumentasi : https://www.geeksforgeeks.org/encapsulation-in-python/

# %% [markdown]
# # Iterator python

# %%
import spacy
# class yang menyimpan teknik pemecah
class Doc:
    def __init__(self, text):
        self.text = text
        self.tokens = [word for word in text.split(',')]
    def __iter__(self):
        for token in self.tokens:
            yield token

class Language:
    def __init__(self, model_name): #model_name dimasukan/inputan objek language
        self.model_name = model_name

    def __call__(self, text): #lalu class ini juga membuat inputan kedua sbg text yang nanti menjadi parameter dalam class Doc ke objeknya
        return Doc(text) #anggap aja kayak lu numpang nama disini, tapi udh keproses langsung gitu ke atas. Disinilah __call__ bekerja dengan membuat objek yang menampung class ini bakalan bisa input text. cek dibawah

# area pemanggilan
objekDoc = Language('en_core_web_sm')

# Process text to create a Doc object
doc = objekDoc("""bought trying""")

for word in doc:
    print(word)
# Out:
# 2024-08-14 09:40:01.671298: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-14 09:40:01.678408: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-14 09:40:01.800341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 09:40:04.560195: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# bought trying

# %% [markdown]
# **QNA**
# 1. apa perbedaan antara iterable vs iterator?

# %%
#  A simple Python program to demonstrate
# working of iterators using an example type
# that iterates from 10 to given value

# An iterable user defined type
class Test:

    # Constructor
    def __init__(self, limit):
        self.limit = limit

    # Creates iterator object
    # Called when iteration is initialized
    def __iter__(self):
        self.x = 10
        return self #kenapa mengembalikan self?

    # To move to next element. In Python 3,
    # we should replace next with __next__
    def __next__(self):

        x = self.x #cuma sebuah variabel yang berisi nilai yang sudah di asign di atas

        # Stop iteration if limit is reached
        if x > self.limit:
            raise StopIteration #ga ada keterangan sebuah eror kah kalo pakai StopIteration?
        #: StopIteration adalah exception khusus yang digunakan untuk menghentikan iterasi. Exception ini tidak memerlukan pesan error karena tujuannya adalah untuk memberi tahu loop bahwa iterasi sudah selesai, bukan untuk menunjukkan bahwa ada error atau masalah. Inilah yang menyebabkan loop for berhenti secara normal tanpa error.

        # Else increment and return old value
        self.x = x + 1;  # apakah code ini yang bikin method next jadi sebuah iterable return?
        return x #knp bukan self.x?

# Prints numbers from 10 to 15
for i in Test(15):
    print(i)

# Prints nothing
for i in Test(5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 33
#      30         return x #knp bukan self.x?
#      32 # Prints numbers from 10 to 15
# ---> 33 for i in Test(15):
#      34     print(i)
#      36 # Prints nothing
#
# Cell In[8], line 22, in Test.__next__(self)
#      20 def __next__(self):
# ---> 22     x = self.y #cuma sebuah variabel yang berisi nilai yang sudah di asign di atas
#      24     # Stop iteration if limit is reached
#      25     if x > self.limit:
#
# AttributeError: 'Test' object has no attribute 'y'

# %% [markdown]
# * cuma paham di bawah doang, yang lain wasalam

# %%
tup = ('a', 'b', 'c', 'd', 'e')

# creating an iterator from the tuple
tup_iter = iter(tup) #index, item versi tunggal isinya

# print("Outside loop:")
print(next(tup_iter))
print(next(tup_iter))
print(next(tup_iter))
print(next(tup_iter))
print(next(tup_iter))
# print(next(tup_iter)) #eror kalo kelebihan, mungkin bisa di raise
# Out:
# a
# b
# c
# d
# e
