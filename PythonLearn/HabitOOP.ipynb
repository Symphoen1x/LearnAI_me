# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/PythonLearn/HabitOOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # sumber link:
# https://chatgpt.com/c/28d763e9-38cd-40f3-908f-2f7ca9be3d1d

# %% [markdown]
# # TO-DO:
# 1. fokus ke studi kasus kedua dulu, tinggal buat method untuk keperluan lain
# 3. sisanya ngurusin yang oop BST bagian traverse, jangan buat method recursive terpisah maka gabungkan jadi satu. buat remove method

# %% [markdown]
# # note
# untuk melakukan undo dan redo pada sel di notebook .ipynb di Google IDX, kamu bisa menggunakan shortcut keyboard standar:
#
# Undo: Tekan Ctrl + Z (Windows/Linux) atau Cmd + Z (Mac) untuk membatalkan tindakan terakhir, termasuk menghapus sel.
# Redo: Tekan Ctrl + Y (Windows/Linux) atau Cmd + Shift + Z (Mac) untuk mengulangi tindakan yang baru saja dibatalkan.

# %% [markdown]
# # Ilmu baru yang didapat dari latihan ini

# %% [markdown]
# * Dalam dict, ada yang namanya nested_dict. bentuknya seperti contoh dibawah.
# * cara mengakesnya:
# value = nested_dict["outer_key1"]["inner_key1"]  # Mengakses 'value1' dari keynya.
# * cara memperbarui nilai ada dibawah.

# %%
# bentuk nested dict:
nested_dict = {  #cara biasa memperbarui nilai nested dict
    "outer_key1": {  #key masih terpisah/blm terakses langsung
        "inner_key1": "value1",
        "inner_key2": "value2"
    },
    "outer_key2": {
        "inner_key3": "value3",
        "inner_key4": "value4"
    }
}

# cara lain memperbarui nilai nested dict:
# cls.daftar_Buku_perpus[cls.isbn] = {  #ini langsung akses ke bagian key sehingga serasa akan memperbarui
#         'title': cls.title,
#         'author': cls.author,
#         'status': 'tersedia'
#     }
#  cara lain lagi lebih simple untuk perbarui nilai dict nested:
# Adding a new key to person1's dictionary
nested_dict['outer_key1']['inner_key1'] = '123-456-7890'

# Updating the city of person2
nested_dict['outer_key2']['inner_key3'] = 'San Francisco'
print(nested_dict)

# # cara hapus dict nested value:
# # Removing the age key from person1
del nested_dict['person1']['age']

# # Removing the entire address dictionary from person2
del nested_dict['person2']['address']

# # cara iterasi/perulanngan dengan dict nested value:
# for person, details in nested_dict.items():
#     print(f'Person: {person}')
#     for key, value in details.items():
#         if isinstance(value, dict):
#             print(f'  {key}:')
#             for sub_key, sub_value in value.items():
#                 print(f'    {sub_key}: {sub_value}')
#         else:
#             print(f'  {key}: {value}')
# Out:
# {'outer_key1': {'inner_key1': '123-456-7890', 'inner_key2': 'value2'}, 'outer_key2': {'inner_key3': 'San Francisco', 'inner_key4': 'value4'}}

# %% [markdown]
# # challange shape area and perimeter

# %%
import math
class Shape():
    def calculate_area(self):
        pass
    def calculate_perimeter(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def calculate_area(self):
        l = math.pi * self.radius**2
        return l
    def calculate_perimeter(self):
        k = 2*math.pi * self.radius
        return k
class Triangle(Shape):
    def __init__(self, alas, tinggi, Skiri, Skanan):
        self.alas = alas
        self.tinggi = tinggi
        self.Skiri = Skiri
        self.Skanan = Skanan
    def calculate_area(self):
        l = 1/2 * alas * tinggi
        return l
    def calculate_perimeter(self):
        k = alas + Skanan + Skiri
        return k
class Rectangle(Shape):
    def __init__(self, sisi):
        self.sisi = sisi
    def calculate_area(self):
        l = sisi**2
        return l
    def calculate_perimeter(self):
        k =  4*sisi
        return k
r = 5
circle = Circle(r)
circle_area = circle.calculate_area()
circle_perimeter = circle.calculate_perimeter()
print(f"Raidus lingkaran: {r}")
print(f"Circle Area: {circle_area}")
print(f"Circle Perimeter: {circle_perimeter}")

# alas = 3
# tinggi = 3
# Skiri = 3
# Skanan  = 3
# triangle = Triangle(alas, tinggi, Skiri, Skanan)
# triangle_area = triangle.calculate_area()
# triangle_perimeter = triangle.calculate_perimeter()
# print(f"triangle sisi: {alas, tinggi, Skiri, Skanan}")
# print(f"triangle Area: {triangle_area}")
# print(f"triangle Perimeter: {triangle_perimeter}")

# sisi = int(input("Masukan value sisi, tapi jangan bernilai negatif: "))
# while sisi < 0:
#     sisi = int(input("Masukan value sisi, tapi jangan bernilai negatif: "))
# Rectangle = Rectangle(sisi)
# Rectangle_area = Rectangle.calculate_area()
# Rectangle_perimeter = Rectangle.calculate_perimeter()
# print(f"Sisi Rectangle: {sisi}")
# print(f"Rectangle Area: {Rectangle_area}")
# print(f"Rectangle Perimeter: {Rectangle_perimeter}")
# Out:
# Raidus lingkaran: 5
# Circle Area: 78.53981633974483
# Circle Perimeter: 31.41592653589793

# %%
import math
class Shape():
    def __init__(self, radius=0, alas=0, tinggi=0, Skiri=0, Skanan=0, sisi=0):
        self.radius = radius
        self.alas = alas
        self.tinggi = tinggi
        self.Skiri = Skiri
        self.Skanan = Skanan
        self.sisi = sisi
    def calculate_area(self):
        return self.radius, self.alas, self.tinggi, self.Skiri, self.Skanan, self.sisi
    def calculate_perimeter(self):
        return self.radius, self.alas, self.tinggi, self.Skiri, self.Skanan, self.sisi
class Circle(Shape):
    def calculate_area(self):
        super().calculate_area()
        l = math.pi * self.radius**2
        return f"luas lingkaran berdasarkan inisiasi: {l}"
    def calculate_perimeter(self):
        super().calculate_perimeter()
        k = 2*math.pi * self.radius
        return f"Keliling lingkaran berdasarkan inisiasi: {k}"
class Triangle(Shape):
    def calculate_area(self):
        super().calculate_area()
        l = 1/2 * alas * tinggi
        return l
    def calculate_perimeter(self):
        super().calculate_perimeter()
        k = alas + Skanan + Skiri
        return k
class Rectangle(Shape):
    def calculate_area(self):
        super().calculate_area()
        l = sisi**2
        return l
    def calculate_perimeter(self):
        super().calculate_perimeter()
        k =  4*sisi
        return k

parent = Shape(0,0,0,0,0,0)
rd = 5
child = Circle(radius=rd)
print(f"input raidus: {rd}")
child.calculate_area()
print(child.calculate_area())
child.calculate_perimeter()
print(child.calculate_perimeter())

# child1 = Triangle(alas=5, tinggi=10, Skanan=10, Skiri=10)
# child1.calculate_area()
# print(child1.calculate_area())
# child1.calculate_perimeter()
# print(child1.calculate_perimeter())

# child2 = Rectangle(sisi=5)
# child2.calculate_area()
# print(child2.calculate_area())
# child2.calculate_perimeter()
# print(child2.calculate_perimeter())
# Out:
# input raidus: 5
# luas lingkaran berdasarkan inisiasi: 78.53981633974483
# Keliling lingkaran berdasarkan inisiasi: 31.41592653589793

# %% [markdown]
# # Challange program BST

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
class Bst:
    def __init__(self): #ini maksudnya bagemana nyak? self dia merujuk ke attribute kelas dia sendiri atau sebelumnya?
        self.root = None    #root menjadi attribute yang didefine tanpa ada argumenya?
    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            return self._insert_recursive(self.root, value)
    def _insert_recursive(self, node, value):
        if value < node.value:
            if node.left is None:
                node.left = Node(value)
            else:
                return self._insert_recursive(node.left, value)
        else:
            if node.right is None:
                node.right = Node(value)
            else:
                return self._insert_recursive(node.right, value)
    def pratraversal(self):
        return self._pratraverse_recursive(self.root)
    def _pratraverse_recursive(self, node):
        # pr susun yang bagian ini jadi kayak:
        # ret = " " * (4 * level) + f"TreeNode({self.val}, {self.left.val if self.left else None}, {self.right.val if self.right else None})\n"
        # if self.left:
        #     ret += self.left._repr_helper(level + 1)
        # if self.right:
        #     ret += self.right._repr_helper(level + 1)
        # return ret


    def search(self, value):
        return self._search_recursive(self.root, value)
    def _search_recursive(self, node, value):
        if node == None or node.value == value:
            return node
        else:
            if value < node.value:
                return self._search_recursive(node.left, value)
            else:
                return self._search_recursive(node.right, value)

bst = Bst()
print("Insert value as initiation")
bst.insert(2)
bst.insert(3)
bst.insert(5)
bst.insert(6)
bst.insert(7)
print(bst.pratraversal())
print("search value as location")
print(bst.search(0))
print(bst.search(2))
print(bst.search(3))
# Out:
#   Cell In[1], line 37
#     def search(self, value):
#     ^
# IndentationError: expected an indented block after function definition on line 27

# %% [markdown]
# # Latihan 1: Sistem Perpustakaan
# sumber: https://chatgpt.com/c/ad525494-0fc4-4106-a404-e609fa82ad37<br>
# Deskripsi:
# Buat sebuah sistem perpustakaan sederhana yang memungkinkan pengguna untuk meminjam dan mengembalikan buku.
#
# Instruksi:
#
# Buat kelas Book yang memiliki atribut seperti title, author, dan ISBN.
# Buat kelas Library yang memiliki atribut seperti books (list dari objek Book) dan borrowed_books (list dari buku yang sedang dipinjam).
# Tambahkan metode di kelas Library untuk:
# Menambahkan buku ke perpustakaan.
# Meminjam buku berdasarkan ISBN.
# Mengembalikan buku berdasarkan ISBN.
# Menampilkan daftar buku yang tersedia di perpustakaan.
# Menampilkan daftar buku yang sedang dipinjam.

# %%
# class book yang berisi beberapa attribute kelas
class book:
# * pakai aattribute kelas biasa
    daftar_Buku_perpus = {} #berisi judul beberapa buku
    # inisiasi isi dulu random apa aja buat template
    title  = str(input("Masukan judul buku: "))
    author = str(input("masukan nama penulis buku: "))
    isbn  = str(input("Masukan ISBN buku tersebut: "))
    @classmethod
    def cek_status(cls):
        if cls.isbn in cls.daftar_Buku_perpus:
            print(f"Status buku {cls.daftar_Buku_perpus[cls.isbn]['title']} adalah {cls.daftar_Buku_perpus[cls.isbn]['status']}")
        else:
            print("Buku tidak ditemukan")
    @classmethod
    def tambah_buku(cls):
        cls.title  = str(input("Masukan judul buku: "))
        cls.author = str(input("masukan nama penulis buku: "))
        cls.isbn  = str(input("Masukan ISBN buku tersebut: ")) #id unik buku
        if cls.isbn not in cls.daftar_Buku_perpus: #kalo blm ada maka ditambahkan ke daftar buku dari inputan
            cls.daftar_Buku_perpus[cls.isbn] = {
                'title': cls.title,
                'author': cls.author,
                'status': 'tersedia'
            }
            print("Buku berhasil ditambahkan")
        else:
            print(f"Buku dengan ISBN {cls.isbn} sudah ada di perpustakaan")
    @classmethod
    def lihat_buku(cls):
        for i in cls.daftar_Buku_perpus:
            if cls.daftar_Buku_perpus[i]['status'] == 'tersedia':
                print(f"* {cls.daftar_Buku_perpus[i]['title']} by {cls.daftar_Buku_perpus[i]['author']}")
            else:
                print("Semua buku di perpus telah dipinjam")
# kelas library yang bersisi beberapa attribute kelas, method operasi, method __str__ berisi format string dan datatype dict
class anggota(book):
    daftar_buku_dipinjam = {} #berisi judul beberapa buku
    # daftar_anggota_peminjam = {}
    # nama = str(input("Masukan nama anggota: "))
    # Id = str(input("Masukan Id anggota: "))
    # @classmethod
    # def tambah_anggota(cls, nama, id):
    #     if Id not in cls.daftar_anggota:
    #         cls.daftar_anggota[Id] = {
    #             'nama' : nama,
    #         }
    #     else:
    #         print("Anggota sudah ada di perpustakaan")
    @classmethod
    def pinjam_buku(cls):
        cls.title = str(input("Masukan judul buku: "))
        cls.author = str(input("masukan nama penulis buku: "))
        cls.isbn  = str(input("Masukan ISBN buku tersebut: ")) #id unik buku
        if cls.isbn not in cls.daftar_buku_dipinjam: #kalo blm ada maka ditambahkan ke daftar buku dari inputan
            if cls.isbn in cls.daftar_Buku_perpus:
                cls.daftar_buku_dipinjam[cls.isbn] = cls.daftar_Buku_perpus[cls.isbn]
                del cls.daftar_Buku_perpus[cls.isbn]
                cls.daftar_Buku_perpus[cls.isbn] = {
                'title': cls.title,
                'author': cls.author,
                'status': 'dipinjam'
            }
                print("Buku berhasil dipinjamkan")
            else:
                print(f"Buku {cls.isbn} tidak ditemukan")
        else:
            print(f"Buku dengan ISBN {cls.isbn} sudah dipinjam")
    @classmethod
    def  kembalikan_buku(cls):
        cls.title = str(input("Masukan judul buku: "))
        cls.author = str(input("masukan nama penulis buku: "))
        cls.isbn  = str(input("Masukan ISBN buku tersebut: ")) #id unik buku
        if cls.isbn in cls.daftar_Buku_perpus: #kalo blm ada maka ditambahkan ke daftar buku dari inputan
            cls.daftar_Buku_perpus[cls.isbn] = cls.daftar_buku_dipinjam[cls.isbn]
            del cls.daftar_buku_dipinjam[cls.isbn]
            cls.daftar_Buku_perpus[cls.isbn] = {
                'title': cls.title,
                'author': cls.author,
                'status': 'tersedia'
            }
            print(f"Buku {cls.title} berhasil ditambahkan")
        else:
            print(f"Buku dengan ISBN {cls.isbn} sudah dikembalikan")

# %%
# sistem pusat perpustakaan yang dihandle oleh admin
p = book.title
q = book.author
r = book.isbn

# %%
# versi 1. masih sama, admin mencoba menginisasi ketersediaan buku.
book.cek_status()
book.tambah_buku()
book.cek_status()
book.lihat_buku()
# Out:
# Buku tidak ditemukan
# Buku berhasil ditambahkan
# Status buku o adalah tersedia
# * o by o

# %%
# code versi 2
book.title = str(input("Masukan judul buku baru : "))
book.author = str(input("Masukan nama penulis buku: "))
book.isbn = str(input("Masukan isbn dari buku tersebut: "))

book.cek_status()
book.tambah_buku()
book.cek_status()
book.lihat_buku()
# Out:
# Buku tidak ditemukan
# Buku berhasil ditambahkan
# Status buku mihawk adalah tersedia
# * qw by ase[
# * mihawk by sipaling

# %%
# inisiasi kedua dari verso 2
book.title = str(input("Masukan judul buku baru : "))
book.author = str(input("Masukan nama penulis buku: "))
book.isbn = str(input("Masukan isbn dari buku tersebut: "))

book.cek_status()
book.tambah_buku()
book.cek_status()
book.lihat_buku()
# Out:
# Buku tidak ditemukan
# Buku berhasil ditambahkan
# Status buku cu adalah tersedia
# * qw by ase[
# * mihawk by sipaling
# * cu by maul

# %% [markdown]
# * note: nanti coba ditambahkan gimana caranya user bisa pilih buku yang spesifik buat dipinjam

# %%
# sistem pusat perpustakaan untuk kebutuhan pengguna

anggota.pinjam_buku()
book.cek_status()
book.lihat_buku()
# anggota.kembalikan_buku()
# Out:
# Buku berhasil dipinjamkan
# Status buku so adalah dipinjam
# Semua buku di perpus telah dipinjam

# %% [markdown]
# # Studi Kasus 2: Sistem Manajemen Kamus Kata Dasar
# Deskripsi:
# Anda ditugaskan untuk membuat sistem manajemen kamus kata dasar yang dapat digunakan dalam berbagai aplikasi NLP. Kamus ini harus mampu menyimpan dan memanipulasi kata dasar, serta mengatur status penggunaannya dalam konteks tertentu.
#
# Skenario:
# Anda perlu mengimplementasikan kelas BasicDictionary yang dapat menyimpan kata dasar beserta informasi terkait seperti sinonim, antonim, dan frekuensi penggunaan kata. Kamus ini juga harus bisa melacak status kata apakah sedang dalam proses review, disetujui, atau ditolak.
#
# Tugas:
#
# Buat kelas BasicDictionary dengan atribut kelas untuk menyimpan daftar kata dasar beserta informasi terkaitnya.
# Implementasikan metode kelas untuk menambah, menghapus, dan memperbarui kata dalam kamus.
# Implementasikan metode kelas untuk mengecek status kata dan mengubah status tersebut berdasarkan input dari pengguna.

# %% [markdown]
# * pendekatan dikte from soal <br>
# kelebihan: <br>
# 1. bisa nambah ilmu dengan cara mengikutinya.
# 2. lebih objektif dalam artian jelas tujuanya
#
# * pendekatan imajinasi form myself

# %%
class BasicDictionary:
    nesteddict = {}

    @classmethod
    def tampilan(cls):
        print("""
        Selamat datang di Sistem Manajemen Kamus Kata Dasar!

        1. Tambah Kata
        2. Hapus Kata
        3. Perbarui Kata
        4. Cek Status Kata
        5. Ubah Status Kata
        6. Tampilkan Semua Kata
        7. Keluar

        """)
        pilihan = int(input("Pilih opsi: "))
        if pilihan == 1:
            cls.menambah()
        elif pilihan == 2:
            cls.cari_kata_spesifik()
        elif pilihan == 3:
            cls.tampilkan_daftar_kata()
        elif pilihan == 4:
            cls.menghapus()
        # elif pilihan == 7:
        #     print("Terima kasih telah menggunakan Sistem Manajemen Kamus Kata Dasar!")
        #     cls.exit()
        else:
            print("Pilihan tidak valid. Silakan coba lagi.")

    @classmethod
    def menambah(cls):
        letak = str(input("Masukan letak kata: "))
        kataDasar = str(input("Masukkan kata dasar: "))
        sinonim = str(input("Masukkan sinonim: "))
        antonim = str(input("Masukkan antonim: "))
        frekuensiUsed = int(input("Masukkan frekuensi penggunaan: "))
        if letak not in cls.nesteddict:  # Perbaikan dari kataDasar ke letak
            cls.nesteddict[letak] = {
                'kata dasar': kataDasar,
                'sinonim': sinonim,
                'antonim': antonim,
                'frekuensi penggunaan': frekuensiUsed,
                'status': 'Aktif'
            }
            print("Kata berhasil ditambahkan")
        else:
            print("Kata sudah ada di dalam kamus")

    @classmethod
    def tampilkan_daftar_kata(cls):
        print("Kata yang ada di dalam kamus:")
        for letak, detail in cls.nesteddict.items():
            print(f"| {letak} | {detail['kata dasar']} | {detail['sinonim']} | {detail['antonim']} | {detail['frekuensi penggunaan']} | {detail['status']} |")

    @classmethod
    def cari_kata_spesifik(cls):
        kataDasar = str(input("Masukkan kata dasar: "))
        found = False
        for key in cls.nesteddict:
            if cls.nesteddict[key]['kata dasar'] == kataDasar:
                print(f"| {key} | {cls.nesteddict[key]['kata dasar']} | {cls.nesteddict[key]['sinonim']} | {cls.nesteddict[key]['antonim']} | {cls.nesteddict[key]['frekuensi penggunaan']} | {cls.nesteddict[key]['status']} |")
                found = True
                print("Kata ditemukan")

        if not found:
            print(found)
            print("Kata tidak ditemukan atau belum ditambahkan")

    #versi 2
    # @classmethod
    # def menghapus(cls):
    #     kataDasar = input("Masukkan kata dasar yang ingin dihapus: ")
    #     for key in list(cls.nesteddict.keys()):
    #         if cls.nesteddict[key]['kata dasar'] == kataDasar:
    #             del cls.nesteddict[key]
    #             print(f"Kata dasar '{kataDasar}' berhasil dihapus")
    #             break  #ini tidak membuat program berhenti, tapi hanya perualangan saja yang berhenti
    #     else:
    #         print("Kata dasar yang Anda masukan tidak ditemukan")

    #     print("Kata yang tersisa di dalam kamus:")
    #     for letak, detail in cls.nesteddict.items(): #method items() berguna agar key-value dalam nested dict bisa terakses. key merupakan letak, value merupakan detail
    #         print(f"| {letak} | {detail['kata dasar']} | {detail['sinonim']} | {detail['antonim']} | {detail['frekuensi penggunaan']} | {detail['status']} |")

    #versi 1
    @classmethod
    def menghapus(cls):
        kataDasar = input("Masukkan kata dasar yang ingin dihapus: ")
        for key in cls.nesteddict:
            if cls.nesteddict[key]['kata dasar'] == kataDasar:
                del cls.nesteddict[key]
                print(f"Kata dasar {kataDasar} berhasil dihapus")
                break
        else:
            print("kata dasar yang anda masukan salah")
        print("Kata yang tersisa di dalam kamus:")
        for key in cls.nesteddict:
            print(f"|{key}|{cls.nesteddict[key]['kata dasar']}| {cls.nesteddict[key]['sinonim']} | {cls.nesteddict[key]['antonim']} | {cls.nesteddict[key]['frekuensi penggunaan']} | {cls.nesteddict[key]['status']} |")
    #versi
    # @classmethod
    # def menghapus(cls):
    #     cls.kataDasar = input("Masukkan kata dasar yang ingin dihapus: ")
    #     for key in cls.nesteddict:
    #         if cls.nesteddict[key]['kata dasar'] == cls.kataDasar:
    #             del cls.nesteddict[key]
    #             print("Kata berhasil dihapus")
    #     else:
    #         print("Kata dasar yang Anda masukan tidak ditemukan")

p = BasicDictionary()
p.tampilan()
p.tampilan()
p.tampilan()
p.tampilan()
p.tampilan()
p.tampilan()


# p.menambah()
# p.menambah()
# p.menambah()

# p.tampilkan_daftar_kata()
# p.cari_kata_spesifik()
# Out:
#         Selamat datang di Sistem Manajemen Kamus Kata Dasar!
#
#         1. Tambah Kata
#         2. Hapus Kata
#         3. Perbarui Kata
#         4. Cek Status Kata
#         5. Ubah Status Kata
#         6. Tampilkan Semua Kata
#         7. Keluar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 110
#      99     # @classmethod
#     100     # def menghapus(cls):
#     101     #     cls.kataDasar = input("Masukkan kata dasar yang ingin dihapus: ")
#    (...)
#     106     #     else:
#     107     #         print("Kata dasar yang Anda masukan tidak ditemukan")
#     109 p = BasicDictionary()
# --> 110 p.tampilan()
#     111 p.tampilan()
#     112 p.tampilan()
#
# Cell In[17], line 18, in BasicDictionary.tampilan(cls)
#       4 @classmethod
#       5 def tampilan(cls):
#       6     print("""
# ...

# %% [markdown]
# # Contoh code yang mencetak beberapa nama dari attribute dari sebuah constructor yang dilingkup ke dalam sebuah dictionary type

# %%
class p:
  def __init__(self, a, b, c):
    self.a = a
    self.b = b
    self.c = c
P = p(1,2,3)
# print(P.__dict__)
for i in P.__dict__:
  print(i)
# Out:
# a
# b
# c

# %% [markdown]
# # code cara bagaimana sebuah parameter bisa di define tapi, simple banget

# %%
def student(id, kelas, name):
  return f"id: {id}, kelas: {kelas,} nama: {name}"

print(student("a12", "12", "abe"))
# Out:
# id: a12, kelas: ('12',) nama: abe
