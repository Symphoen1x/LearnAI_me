# %% [markdown]
# <a href="https://colab.research.google.com/github/Symphoen1x/LearnAI-NLP/blob/main/overview_word_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Format TO-DO theory
# 1. baca dulu materinya sampai selesai satu sumber
# 2. kritisi dan ulik sampai paham dan tidak ada kebingungan
# 3. catat informasi yang sekiranya di sumber tidak ada/kurang jelas, tapi bisa ditemukan di AI/sumber lain.
#
#
# # TO-DO practic
# 1. pahami implementasi code beberapa library dari sumber terbaik alias dokumentasi sumbernya untuk memahami fitur-fitur dan parameternya(usahakan fokus pada bagaimana library sesuai dengan konsep dasar yang dipelajari di teori)
#
# [optional]
# 2. coba ulik apa yang membedakan kemampuan dan hasil library satu denga lainya
# 3. buat catatan kelebihan dan kekurangan masing-masing library dalam implementasinya pakai bantuan AI

# %% [markdown]
# # Main sumber
# * YT code basic word vector: https://www.youtube.com/watch?v=Fuw0wv3X-0o&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=40
# * dicoding : https://www.dicoding.com/academies/185/tutorials/37403
# * https://www.geeksforgeeks.org/word-embeddings-in-nlp/ = first
# * chatGPT = asistent - Geeks

# %% [markdown]
# # Note
# 1. kali ini baru sampai perisapan dan pengenalan lalu gw memutuskan buat next, gw mau fokus pemahaman konsep di Code basic sedangkan praktik prgramming bisa dari gfg atau code basic juga atau others.
# 1. karena butuh pendalaman neural network/deep learning, gw memutuskan buat tau codenya dan bagaimana implementasinya aja? coba mulai dulu step 1! kalo emang kesusahan gw mundur dulu dan lakukan step 2!

# %% [markdown]
# # Target today
# [time]-[input: topic objektif learning]-[spesifik link]-[output]
# 1. 11/11/24-review word embeding sebelum masuk ke NN via wejangan gfg dan yang primary di code basic-https://www.youtube.com/watch?v=Fuw0wv3X-0o&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=40 & https://www.geeksforgeeks.org/word-embeddings-in-nlp/ - output:
# * done nyipain format belajar + alogritma
# * done baca topik word embeding from gfg

# %% [markdown]
# # extract data to collecting information
# # Theory:
# ## Pengenalan
# 1. apa sih kelebihan dan kegunaan word embedding?
# * simplenya biar dimensi vektor itu tidak to much
# * terus dia itu bisa predik kata terdekat yang membantu mencari sinonim suatu kata
# * terkahir dia itu bisa menangkap makna atau semantik suatu kata
# 2. **jelaskan lebih terkait kegunaan word embedding untuk memvisualisasi pola penggunaan yang mendasar korpus yang dipakai untuk melatihnya!**
# 3. Apa saja pendekatan word embedding dan juga apa saja jenis tekniknya?
# *  CBOW & skip gram
# Word2vec, Glovel
# *  Based on trasnformer architecture
# BERT, GPT
# *  Based on LSTM, ELMo
# 4. Apa saja hubungan semantik yang dapat ditangkap oleh word embedding? in dicoding.
# 5. Katanya si word embedding adalah metode untuk menangani issue si BOW, BON, TF-IDF? dari sisi mananya?
# https://chatgpt.com/c/66e507b0-c7a0-8009-b0b0-33bef2c446dc
# 6. pada saat kondisi (data/dll) seperti apa jika kita menggunakan word embedding akan menjadi langkah yang tepat? https://chatgpt.com/c/66e507b0-c7a0-8009-b0b0-33bef2c446dc
# 7. apa saja kekurangan dari word embedding?
# https://chatgpt.com/c/66e507b0-c7a0-8009-b0b0-33bef2c446dc#:~:text=apa%20saja%20kekurangan%20dari%20word%20embedding%3F
#
# * kritisasi video yang ada di code basic
# 8.
#
#
#
# ## Neural Approach
# (https://www.geeksforgeeks.org/python-word-embedding-using-word2vec/)
#
# 1. apakah matriks kemunculan/co-occurrence matrix yang ada di GloVe sama dengan yang ada di BOW/BON/DF? https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248
# 2. jendela konteks dalam hal ini maksudnya apa ya? jendela apa, konteks apa?
# https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248
# 3. Semakin Sering Kemunculan Bersama sebuah kata dalam jendela/windows dari kata target maka Hubungan semantiknya Semakin Kuat. maksudnya apa ya? : https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248
#
# # Technical<br>
# 1.
# model = Word2Vec(sentences=tokenized_data, vector_size=100, window=5, min_count=1, workers=4)
#
# dari parameter diatas, Saya masih bingung terkait parameter workers dalam model Word2Vec, kan katanya berhubungan dengan jumlah thread? apa itu jumlah thread?: cek https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248
# * Namun, seberapa banyak thread yang dapat kamu gunakan tergantung pada jumlah core CPU yang tersedia pada komputer kamu.
# Bagaimana cara menentukan thread dengan tepat? https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248
# 2. katanya kan dalam vektor sebuah kata yang menjadi representasi matematis dari sebuah kata dalam ruang vektor yang ada di word_vecotr dari Word2Vec model, isinya itu berupa fitur/atribute tertentu yang mewakili sebuah kata(target). bagaimana proses pembentukanya? apakah ada prioritas tertentu yang mengharuskan sebuah fitur berada di awal? = hold
# 3. word_vectors = model.wv
#
# similar_words = word_vectors.most_similar('bakso', topn=3),
# apa itu topn? = https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248

# %% [markdown]
# # complex
# (https://chatgpt.com/c/66e34cdc-c6c0-800b-b603-7fe639937248)
#
#
#
# 1. word embedding:
# 4. Word2vec
# 2. skip-gram
# 3. CBOW
# 2. sentence embedding
# 3. doc embedding
# 6. ELMo
# 2. Glove
# 4. co-occurrence matrix
# 3. fastext
# 4. BERT
# 5. GPT

# %% [markdown]
# # QNA theory
# [ini nanti akhir dimasukin ke sini sementara masih di tampung dulu di extract data to collecting inform]

# %% [markdown]
# # QNA technique
# [ini nanti akhir dimasukin ke sini sementara masih di tampung dulu di extract data to collecting inform]

# %% [markdown]
# # !!! Praktik with library di bawah hold dulu karena gw belum paham theorynya dengan holistik

# %% [markdown]
# # Information to documentation with spacy:

# %%
import spacy
# !python -m spacy download en_core_web_lg
# word vectors occupy lot of space. hence en_core_web_sm model do not have them included.
# In order to download
# word vectors you need to install large or medium english model. We will install the large one!
# make sure you have run "python -m spacy download en_core_web_lg" to install large english model
nlp = spacy.load("en_core_web_lg")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
doc = nlp("dog cat banana kem")

for token in doc:
    print(token.text, "Vector:", token.has_vector, "OOV:", token.is_oov)
# Out:
# dog Vector: True OOV: False
# cat Vector: True OOV: False
# banana Vector: True OOV: False
# kem Vector: False OOV: True

# %%
doc[0].vector.shape
# Out:
# (300,)

# %%
base_token = nlp("bread")
base_token.vector.shape
# Out:
# (300,)

# %%
doc = nlp("bread sandwich burger car tiger human wheat")

for token in doc:
    print(f"{token.text} <-> {base_token.text}:", token.similarity(base_token))
# Out:
# bread <-> bread: 0.9999999744752309
# sandwich <-> bread: 0.6341067010130894
# burger <-> bread: 0.47520687769584247
# car <-> bread: 0.06451533308853552
# tiger <-> bread: 0.04764611675903374
# human <-> bread: 0.2151154210812192
# wheat <-> bread: 0.6150360888607199

# %%
def print_similarity(base_word, words_to_compare):
    base_token = nlp(base_word)
    doc = nlp(words_to_compare)
    for token in doc:
        print(f"{token.text} <-> {base_token.text}: ", token.similarity(base_token))

# %%
print_similarity("iphone", "apple samsung iphone dog kitten")
# Out:
# apple <-> iphone:  0.4387907401919904
# samsung <-> iphone:  0.670859081425417
# iphone <-> iphone:  1.0
# dog <-> iphone:  0.08211864228011527
# kitten <-> iphone:  0.10222317834969896

# %% [markdown]
# # Information to documentation with gensim:
# All gensim models are listed on this page: https://github.com/RaRe-Technologies/gensim-data

# %%
import gensim.downloader as api

# %%
wv = api.load('word2vec-google-news-300')

# %%
# how to check similarity words
wv.similarity(w1="great", w2="good")

# %%
# How to find the most similarity
wv.most_similar("good")

# %%
# how to make analogy similarity like sinonim and antonim
wv.most_similar(positive=['king', 'woman'], negative=['man'], topn=5)

# %%
# how to check word that doesn't match with other
wv.doesnt_match(["facebook", "cat", "google", "microsoft"])

# %% [markdown]
# # Information to documentation with gensim for Word2Vec model

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

corpus = api.load('text8')  # download the corpus and return it opened as an iterable
model = Word2Vec(corpus)  # train a model from the corpus
model.most_similar("car")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f9cffbba7b21> in <cell line: 5>()
#       3
#       4 corpus = api.load('text8')  # download the corpus and return it opened as an iterable
# ----> 5 model = Word2Vec(corpus)  # train a model from the corpus
#       6 model.most_similar("car")
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428             self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
# ...

# %% [markdown]
# # Information to documentation with gensim for glove
# cek this: https://github.com/piskvorky/gensim-data

# %%
glv = api.load("glove-twitter-25")
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
glv.most_similar("good")
# Out:
# [('too', 0.9648017287254333),
#  ('day', 0.9533665180206299),
#  ('well', 0.9503170847892761),
#  ('nice', 0.9438973665237427),
#  ('better', 0.9425962567329407),
#  ('fun', 0.9418926239013672),
#  ('much', 0.9413353800773621),
#  ('this', 0.9387555122375488),
#  ('hope', 0.9383506774902344),
#  ('great', 0.9378516674041748)]

# %%
glv.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'
